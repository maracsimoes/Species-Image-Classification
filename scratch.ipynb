# %% [markdown]
# # **Models from scratch**

# %% [markdown]
# [<font color='steelblue'>1. - __EDA__</font>](#one-bullet) <br>
#     [<font color='steelblue'>1.1. - Import Libraries</font>](#two-bullet) <br>
#     [<font color='steelblue'>1.2. - Import Data Files</font>](#three-bullet) <br>
#     [<font color='steelblue'>1.3. - PreProcessing</font>](#four-bullet) <br>
#     [<font color='steelblue'>1.4. - Removing Outliers</font>](#five-bullet) <br>
#     [<font color='steelblue'>1.5. - Augmentation</font>](#six-bullet) <br>
#
# [<font color='steelblue'>2. - __Models__</font>](#seven-bullet) <br>
#     [<font color='steelblue'>2.1. - PreModel</font>](#eight-bullet) <br>
#     [<font color='steelblue'>2.2. - Sequential</font>](#nine-bullet) <br>
#     [<font color='steelblue'>2.3. - Functional</font>](#ten-bullet) <br>
#     [<font color='steelblue'>2.4. - Functional with more layers</font>](#eleven-bullet) <br>
#     [<font color='steelblue'>2.5. - Class imbalance - last try</font>](#twelve-bullet) <br>

# %% [markdown]
# Group 07
# |Name | Number |
# |----|----|
# |Fábio dos Santos| 2024|
# |Joana Rodrigues| 20240603|
# |Mara Simões| 20240326|
# |Matilde Street| 20240523|
# |Rafael Borges| 20240497|

# %% [markdown]
# <hr>
# <a class="anchor" id="one-bullet">
# <d style="color:white;">
#
# ## 1. EDA
# </a>
# </d>

# %% [markdown]
# <a class="anchor" id="two-bullet">
# <d style="color:white;">
#
# ### 1.1. Import Libraries
# </a>
# </d>

# %%
import math
import shutil
from pathlib import Path
import numpy as np
import pandas as pd
import pickle

# Visualization
import matplotlib.pyplot as plt
import plotly.express as px

# TensorFlow and Keras
import tensorflow as tf
from tensorflow import add
from tensorflow.keras import layers, models, optimizers, losses
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import CategoricalAccuracy, AUC, SparseCategoricalAccuracy
from keras.layers import LeakyReLU
from keras.utils import to_categorical
from keras.metrics import F1Score
from keras.optimizers import Adam, RMSprop
import keras.backend as K
from tensorflow.keras.callbacks import EarlyStopping

# Preprocessing 
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import class_weight

# Outlier Detection
import hdbscan
from tensorflow.keras.applications import VGG16
from transformers import CLIPProcessor, TFCLIPModel
from sklearn.ensemble import IsolationForest
from sklearn.metrics.pairwise import cosine_distances
import os
import shutil

# Augmentation
from keras.layers import RandomBrightness, RandomContrast, RandomFlip, RandomRotation, RandomSaturation, Pipeline

# Bayesian optimization
#from keras_tuner import BayesianOptimization
#from keras.callbacks import Callback, EarlyStopping
#import wandb
#from wandb.integration.keras import WandbCallback
# Out:
# WARNING:tensorflow:From c:\Users\joana\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# <a class="anchor" id="three-bullet">
# <d style="color:white;">
#
# ### 1.2. Import Data Files
# </a>
# </d>
# Firstly we create the path and after we will load the data files

# %%
path = Path('.') / 'data' / 'metadata.csv'

df = pd.read_csv(path)

# Display the first few rows of the dataframe to verify
df
# Out:
#                             rare_species_id  eol_content_id  eol_page_id  \
# 0      75fd91cb-2881-41cd-88e6-de451e8b60e2        12853737       449393
# 1      28c508bc-63ff-4e60-9c8f-1934367e1528        20969394       793083
# 2      00372441-588c-4af8-9665-29bee20822c0        28895411       319982
# 3      29cc6040-6af2-49ee-86ec-ab7d89793828        29658536     45510188
# 4      94004bff-3a33-4758-8125-bf72e6e57eab        21252576      7250886
# ...                                     ...             ...          ...
# 11978  1fa96ea5-32fa-4a25-b8d2-fa99f6e2cb89        29734618      1011315
# 11979  628bf2b4-6ecc-4017-a8e6-4306849e0cfc        29972861      1056842
# 11980  0ecfdec9-b1cd-4d43-96fc-2f8889ec1ad9        30134195     52572074
# 11981  27fdb1e9-c5fb-459a-8b6a-6fb222b1c512         9474963     46559139
# 11982  54894a59-151f-4814-ac32-3a336841e58e         9465817       326525
#
#         kingdom    phylum            family  \
# 0      animalia  mollusca         unionidae
# 1      animalia  chordata       geoemydidae
# 2      animalia  chordata  cryptobranchidae
# 3      animalia  chordata          turdidae
# 4      animalia  chordata         indriidae
# ...         ...       ...               ...
# 11978  animalia  chordata         leporidae
# 11979  animalia  chordata          emydidae
# 11980  animalia  chordata        dasyatidae
# 11981  animalia  chordata        mustelidae
# 11982  animalia  chordata         lemuridae
#
#                                                file_path
# 0      mollusca_unionidae/12853737_449393_eol-full-si...
# 1      chordata_geoemydidae/20969394_793083_eol-full-...
# 2      chordata_cryptobranchidae/28895411_319982_eol-...
# 3      chordata_turdidae/29658536_45510188_eol-full-s...
# 4      chordata_indriidae/21252576_7250886_eol-full-s...
# ...                                                  ...
# 11978  chordata_leporidae/29734618_1011315_eol-full-s...
# 11979  chordata_emydidae/29972861_1056842_eol-full-si...
# 11980  chordata_dasyatidae/30134195_52572074_eol-full...
# 11981  chordata_mustelidae/9474963_46559139_eol-full-...
# 11982  chordata_lemuridae/9465817_326525_eol-full-siz...
#
# [11983 rows x 7 columns]

# %% [markdown]
# In the previous notebook we got the data splited.
# In this we import it and for the train we import the 3 different strategies we created in the previous notebook. The three of them were tested with the models and the best is kept uncommented.
# - original train with no modifications
# - train with removal of 'outliers' based on the clip model (best results from the three different approaches tried in the previous notebook)
# - train with removal of outliers and augmentation on the minority classes.

# %%
def get_image_paths_and_labels(base_path):
    base = Path(base_path)
    image_paths = list(base.rglob("*.jpg"))  
    data = {
        "filepath": [str(p) for p in image_paths],
        "label": [p.parent.name for p in image_paths]
    }
    return pd.DataFrame(data)


# Get the paths and labels for train, val, and test sets
dest_root = Path('.') / "data_split"
#train_df = get_image_paths_and_labels(dest_root / 'train')
train_df = get_image_paths_and_labels(Path('.')/'data_clean_clip')
train_df_aug = get_image_paths_and_labels(Path('.') / 'data_aug_clip')
val_df = get_image_paths_and_labels(dest_root / 'val')
test_df = get_image_paths_and_labels(dest_root / 'test')

# %% [markdown]
# <a class="anchor" id="four-bullet">
# <d style="color:white;">
#
# ### 1.3. PreProcessing
# </a>
# </d>
# After the load of the data we proceed to do the remaining preprocessing steps here.
#
# #### 1.3.1. Encoder
# Encoder: We load a pickle that saves the encoder created in the previous notebook for the train to avoid data leakage. We apply this to the validation and the test dataset so they all have the same values for the same classes.
# After this we save the paths and the labels for each of the subset of the data to later use.

# %%
encoder = pickle.load(open("encoder.pkl", 'rb'))
val_df["label_encoded"] = encoder.transform(val_df["label"])
test_df["label_encoded"] = encoder.transform(test_df["label"])

# %%
train_labels = tf.constant(train_df["label"].astype(int).values)
train_paths = tf.constant(train_df["filepath"].values)

train_labels_aug = tf.constant(train_df_aug["label"].astype(int).values)
train_paths_aug = tf.constant(train_df_aug["filepath"].astype(str).values)

val_paths = tf.constant(val_df["filepath"].values)
val_labels = tf.constant(val_df["label_encoded"].values)

test_paths = tf.constant(test_df["filepath"].values)
test_labels = tf.constant(test_df["label_encoded"].values)


train_dataset = tf.data.Dataset.from_tensor_slices((train_paths, train_labels))
train_dataset_aug = tf.data.Dataset.from_tensor_slices((train_paths_aug, train_labels_aug))
val_dataset = tf.data.Dataset.from_tensor_slices((val_paths, val_labels))
test_dataset = tf.data.Dataset.from_tensor_slices((test_paths, test_labels))

# %% [markdown]
# #### 1.3.2. Padding function
# This adds extra pixels to the pictures that are not a specific sizes (0s or a constant value) to avoid distortion of images and loss of information.

# %%
def resize_with_padding(image, target_height=224, target_width=224):
    shape = tf.shape(image)[:2] 
    height, width = tf.cast(shape[0], tf.float32), tf.cast(shape[1], tf.float32)

    scale = tf.minimum(target_width / width, target_height / height)
    new_height = tf.cast(height * scale, tf.int32)
    new_width = tf.cast(width * scale, tf.int32)

    resized_image = tf.image.resize(image, [new_height, new_width])

    pad_height = (target_height - new_height) // 2
    pad_width = (target_width - new_width) // 2
    padded_image = tf.image.pad_to_bounding_box(resized_image, pad_height, pad_width, target_height, target_width)

    return padded_image

# %% [markdown]
# #### 1.3.3. Preprocessing application
# In here we create a function `decode_img` that will apply several different preprocessing steps to the images:
# 1. Reads the images
# 2. Decodes them from the JPEG format to be used as a tensor
# 3. Zooms (crops) the image 80% so that if the animal is too far away it can be read more clearly.
# 4. Usage of the padding function created previously.
# 5. Normalization to help the model train better (consistent scale, no bias)
# 6. Labels turned into one-hot encoding because it works best in NN with multiclass classification.

# %%
# Normalizing with 2 different methods to see which one works better
normalization_layer = tf.keras.layers.Rescaling(1./255) # 0-1 normalization
# normalization_layer = tf.keras.layers.Rescaling(1./127.5, offset=-1) # -1 to 1 normalization

def decode_img(img_path, label):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.central_crop(img, central_fraction=0.8)
    img = resize_with_padding(img) 
    #img = tf.image.resize(img, [224, 224]) # this was previously applied but the results were not as good
    img = normalization_layer(img)
    label = tf.one_hot(label, depth=202)
    return img, label


train_dataset = train_dataset.map(decode_img).batch(32).prefetch(tf.data.AUTOTUNE)
train_dataset_aug = train_dataset_aug.map(decode_img).batch(32).prefetch(tf.data.AUTOTUNE)
val_dataset = val_dataset.map(decode_img).batch(32).prefetch(tf.data.AUTOTUNE)
test_dataset = test_dataset.map(decode_img).batch(32).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# <a class="anchor" id="five-bullet">
# <d style="color:white;">
#
# ### 1.4. Removing Outliers
# </a>
# </d>

# %% [markdown]
# - 1st with DBSCAN
# - 2nd with VGG16
# - 3rd with CLIP
#
# We did it in the "eda" notebook and the best method was with CLIP, so from now on we will use the train dataset without the outliers identified with CLIP

# %%
# dest_root = Path('.') 
# # data_clean_dbscan = get_image_paths_and_labels(dest_root / 'data_clean_dbscan')
# # data_clean_vgg16 = get_image_paths_and_labels(dest_root / 'data_clean_vgg16')
# data_clean_clip = get_image_paths_and_labels(dest_root / 'data_clean_clip')
# train_dataset = data_clean_clip
# train_df["label_encoded"] = encoder.transform(train_df["label"])
# train_paths = tf.constant(train_df["filepath"].values)
# train_labels = tf.constant(train_df["label_encoded"].values)
# train_dataset = tf.data.Dataset.from_tensor_slices((train_paths, train_labels))

# %% [markdown]
# <a class="anchor" id="six-bullet">
# <d style="color:white;">
#
# ### 1.4. Augmentation
# </a>
# </d>
#
# Augmentation is important because it gives the model more variety in the images it sees. We used it before to help with the minority classes, but this time we applied it to all classes to try both approaches.

# %%
augmentation_layer = Pipeline([
    RandomBrightness(factor=0.1, value_range=(0.0, 1.0)),
    RandomSaturation(factor=0.2),
    RandomContrast(factor=0.2),
    RandomFlip(),
    RandomRotation(0.1)
])

# %%
def show_random_original_and_augmented(dataset, augmentation_layer):
    dataset = dataset.shuffle(1000)  # embaralha o dataset

    for images, _ in dataset.take(1):
        image = images[0]  # pega a primeira imagem do batch embaralhado
        augmented_image = augmentation_layer(tf.expand_dims(image, 0))[0]

        plt.figure(figsize=(10, 5))

        # Original
        plt.subplot(1, 2, 1)
        plt.imshow(image.numpy())
        plt.title("Original Image")
        plt.axis("off")

        # Augmented
        plt.subplot(1, 2, 2)
        plt.imshow(augmented_image.numpy())
        plt.title("Augmented Image")
        plt.axis("off")

        plt.show()
        break

# %%
#show_random_original_and_augmented(train_dataset, augmentation_layer)

# %% [markdown]
# <a class="anchor" id="six-bullet">
# <d style="color:white;">
#
# ### 1.5. Class weights
# </a>
# </d>
# Another technique to fight class imbalance tried is the class weights.
# This, when applied to the model, makes the images from the minority classes have more weight in the decision.

# %%
train_labels_np = np.array(train_labels)

# Compute the class weights
class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_labels_np),
    y=train_labels_np
)

# Create a dictionary mapping class indices to their weights
class_weight_dict = {i: class_weights[i] for i in range(len(class_weights))}
class_weight_dict
# Out:
# {0: 0.3878825382538254,
#  1: 1.8963146314631463,
#  2: 0.9752475247524752,
#  3: 1.8963146314631463,
#  4: 1.8963146314631463,
#  5: 0.22021718300862345,
#  6: 0.9481573157315731,
#  7: 1.8963146314631463,
#  8: 1.8963146314631463,
#  9: 1.8963146314631463,
#  10: 1.8963146314631463,
#  11: 1.8963146314631463,
#  12: 1.8963146314631463,
#  13: 1.8963146314631463,
#  14: 1.8963146314631463,
#  15: 1.8963146314631463,
#  16: 1.8963146314631463,
#  17: 0.4876237623762376,
#  18: 0.7111179867986799,
#  19: 0.9481573157315731,
#  20: 2.0078625509609784,
#  21: 2.1333539603960396,
#  22: 1.8963146314631463,
#  23: 0.9481573157315731,
#  24: 0.9481573157315731,
#  25: 0.3923409582337544,
#  26: 0.9481573157315731,
#  27: 0.9481573157315731,
#  28: 0.9481573157315731,
#  29: 2.1333539603960396,
#  30: 0.4015725101921957,
#  31: 1.8963146314631463,
#  32: 1.8963146314631463,
#  33: 1.8963146314631463,
#  34: 0.9752475247524752,
#  35: 1.8963146314631463,
#  36: 0.2687690028845404,
#  37: 1.8963146314631463,
#  38: 0.2994180997047073,
#  39: 0.37926292629262925,
#  40: 0.9481573157315731,
#  41: 2.0078625509609784,
#  42: 0.48075582206107936,
#  43: 2.0078625509609784,
#  44: 2.0078625509609784,
#  45: 0.22456357477853048,
#  46: 1.8963146314631463,
#  47: 0.7111179867986799,
#  48: 0.22021718300862345,
#  49: 1.8963146314631463,
#  50: 1.8963146314631463,
#  51: 0.9481573157315731,
#  52: 1.0039312754804892,
#  53: 0.9481573157315731,
#  54: 1.8963146314631463,
#  55: 1.0039312754804892,
#  56: 1.8963146314631463,
#  57: 2.1333539603960396,
#  58: 0.6692875169869928,
#  59: 0.6692875169869928,
#  60: 1.8963146314631463,
#  61: 0.9481573157315731,
#  62: 1.8963146314631463,
#  63: 0.9481573157315731,
#  64: 0.9481573157315731,
#  65: 1.8963146314631463,
#  66: 1.8963146314631463,
#  67: 2.0078625509609784,
#  68: 0.20687068706870687,
#  69: 1.8963146314631463,
#  70: 0.42140325143625473,
#  71: 1.8963146314631463,
#  72: 1.8963146314631463,
#  73: 1.8963146314631463,
#  74: 0.5094576621841289,
#  75: 1.8963146314631463,
#  76: 0.35555899339933994,
#  77: 0.9481573157315731,
#  78: 2.0078625509609784,
#  79: 0.9752475247524752,
#  80: 1.8963146314631463,
#  81: 1.8963146314631463,
#  82: 0.9752475247524752,
#  83: 0.9481573157315731,
#  84: 1.8963146314631463,
#  85: 1.8963146314631463,
#  86: 0.6321048771543821,
#  87: 2.0078625509609784,
#  88: 1.8963146314631463,
#  89: 1.8963146314631463,
#  90: 1.8963146314631463,
#  91: 1.8963146314631463,
#  92: 1.8963146314631463,
#  93: 0.9752475247524752,
#  94: 1.8963146314631463,
#  95: 1.8963146314631463,
#  96: 0.6321048771543821,
#  97: 1.8963146314631463,
#  98: 0.5251332825590251,
#  99: 1.8963146314631463,
#  100: 0.9481573157315731,
#  101: 0.9481573157315731,
#  102: 1.8963146314631463,
#  103: 0.42667079207920794,
#  104: 1.8963146314631463,
#  105: 0.9752475247524752,
#  106: 0.9752475247524752,
#  107: 2.0078625509609784,
#  108: 0.9481573157315731,
#  109: 2.0078625509609784,
#  110: 2.0078625509609784,
#  111: 1.8963146314631463,
#  112: 1.8963146314631463,
#  113: 1.8963146314631463,
#  114: 1.8963146314631463,
#  115: 2.0078625509609784,
#  116: 0.6564166031987814,
#  117: 0.6564166031987814,
#  118: 1.8963146314631463,
#  119: 1.8963146314631463,
#  120: 0.9481573157315731,
#  121: 1.8963146314631463,
#  122: 1.8963146314631463,
#  123: 2.0078625509609784,
#  124: 1.8963146314631463,
#  125: 1.8963146314631463,
#  126: 1.8963146314631463,
#  127: 1.8963146314631463,
#  128: 1.8963146314631463,
#  129: 1.8963146314631463,
#  130: 1.8963146314631463,
#  131: 1.8963146314631463,
#  132: 0.22755775577557755,
#  133: 1.8963146314631463,
#  134: 1.8963146314631463,
#  135: 1.8963146314631463,
#  136: 2.0078625509609784,
#  137: 1.8963146314631463,
#  138: 1.8963146314631463,
#  139: 0.7757650765076508,
#  140: 0.4876237623762376,
#  141: 0.9481573157315731,
#  142: 0.9752475247524752,
#  143: 0.6564166031987814,
#  144: 1.8963146314631463,
#  145: 2.0078625509609784,
#  146: 0.6440313842705025,
#  147: 1.8963146314631463,
#  148: 0.9481573157315731,
#  149: 1.8963146314631463,
#  150: 0.9752475247524752,
#  151: 0.2188055343995938,
#  152: 2.0078625509609784,
#  153: 1.8963146314631463,
#  154: 1.8963146314631463,
#  155: 1.0666769801980198,
#  156: 1.8963146314631463,
#  157: 0.6826732673267327,
#  158: 2.0078625509609784,
#  159: 1.8963146314631463,
#  160: 1.8963146314631463,
#  161: 0.9481573157315731,
#  162: 0.5251332825590251,
#  163: 0.7262481567305666,
#  164: 1.8963146314631463,
#  165: 2.0078625509609784,
#  166: 1.8963146314631463,
#  167: 2.1333539603960396,
#  168: 0.9481573157315731,
#  169: 0.9752475247524752,
#  170: 0.6564166031987814,
#  171: 1.8963146314631463,
#  172: 0.6564166031987814,
#  173: 1.8963146314631463,
#  174: 1.8963146314631463,
#  175: 0.9481573157315731,
#  176: 1.8963146314631463,
#  177: 1.0039312754804892,
#  178: 2.0078625509609784,
#  179: 0.9481573157315731,
#  180: 1.8963146314631463,
#  181: 1.8963146314631463,
#  182: 1.8963146314631463,
#  183: 0.2752714787607793,
#  184: 0.48075582206107936,
#  185: 1.8963146314631463,
#  186: 1.8963146314631463,
#  187: 0.6321048771543821,
#  188: 0.9481573157315731,
#  189: 1.8963146314631463,
#  190: 1.8963146314631463,
#  191: 2.0078625509609784,
#  192: 1.8963146314631463,
#  193: 0.9481573157315731,
#  194: 0.9481573157315731,
#  195: 1.8963146314631463,
#  196: 0.9481573157315731,
#  197: 0.9481573157315731,
#  198: 1.8963146314631463,
#  199: 1.8963146314631463,
#  200: 0.9481573157315731,
#  201: 1.8963146314631463}

# %% [markdown]
# <hr>
# <a class="anchor" id="seven-bullet">
# <d style="color:white;">
#
# ## 2. Models
# </a>
# </d>

# %% [markdown]
# <a class="anchor" id="eight-bullet">
# <d style="color:white;">
#
# ### 2.1. PreModel
# </a>
# </d>
# Definition of metrics and input shape. Reasons for choice of metrics:
#
# |**Metric used** | **Reason**|
# |----------------|----------------------------------------------------------------------------------------------|
# |**Accuracy**| Gives an overall idea of performance, but not very good because it's misleading with such an imbalanced dataset.|
# |**Precision**| Says how often a model is correct when it says it's a specific class.|
# |**Recall**| Tell how many times an image classification is right in comparison to the total there is of that image |
# |**F1 Score**| Balances precision and recall. good for our imbalanced 202-class problem.|
# |**Loss** (later shown)| Good to see how well the model is learning. The lower the best (model more confident and performative)|

# %%
input_shape = (224, 224, 3)
n_classes = 202


categorical_accuracy = CategoricalAccuracy(name="accuracy")
precision = CategoricalAccuracy(name="precision")
recall = CategoricalAccuracy(name="recall")
f1_score = F1Score(average="macro", name="f1_score")
metrics = [categorical_accuracy,precision, recall, f1_score]

# %% [markdown]
# #### Functions to Investigate the Class Prediction of the Dataset
#
# 1. **Class Report**: This function generates a detailed report on the model’s predictions, showing the correct and incorrect predictions, as well as the certainty levels associated with each class.
#
# 2. **Most predictions**: Most frequent predicted classes in the dataset --> may be confunding the dataset
#
# 3. **no_predictions_or_incorrect**: Classes that are not being predicted at all or are incorrectly predicted --> useful for maybe unbalancing metrics...
#
# 4. **Average Certainty Calculation**:  average certainty (as a percentage) for correct and incorrect predictions (how confident the model is in the predictions) --> useful maybe for thresholding (maybe for the folder others???)

# %%
# def class_report(model):

#     # Getting the true labels from the dataset
#     y_true = []
#     for images, labels in test_dataset:
#         y_true.extend(labels.numpy())  # Store true labels

#     # Get the prediction probabilities from the model
#     y_pred_prob = model.predict(test_dataset, verbose=0)

#     # Get the predicted class labels (class with the highest probability)
#     y_pred_classes = np.argmax(y_pred_prob, axis=1)

#     # Convert y_true to numpy and get the class labels if one-hot encoded
#     y_true = np.argmax(np.array(y_true), axis=1)

#     # Initialize counters for correct and incorrect predictions and their respective certainties
#     correct_predictions = [0] * len(np.unique(y_true))
#     incorrect_predictions = [0] * len(np.unique(y_true))
#     correct_certainties = [0] * len(np.unique(y_true))
#     incorrect_certainties = [0] * len(np.unique(y_true))

#     # Calculate predictions and certainties for each class
#     for class_idx in range(len(np.unique(y_true))):  # Loop over all classes
#         correct_mask = (y_true == class_idx) & (y_pred_classes == class_idx)
#         incorrect_mask = (y_true == class_idx) & (y_pred_classes != class_idx)

#         if np.any(correct_mask):
#             correct_certainty = np.max(y_pred_prob[correct_mask], axis=1)
#             correct_certainties[class_idx] = np.mean(correct_certainty)  # Mean certainty for the class
#             correct_predictions[class_idx] = np.sum(correct_mask)

#         if np.any(incorrect_mask):
#             incorrect_certainty = np.max(y_pred_prob[incorrect_mask], axis=1)
#             incorrect_certainties[class_idx] = np.mean(incorrect_certainty)  # Mean certainty for the class
#             incorrect_predictions[class_idx] = np.sum(incorrect_mask)

#     # Create a DataFrame with the information
#     class_report = pd.DataFrame({
#         'True Class': y_true,
#         'Predicted Class': y_pred_classes,
#         'Correct Predictions': correct_predictions,
#         'Incorrect Predictions': incorrect_predictions,
#         'Certainty of Correct': correct_certainties,
#         'Certainty of Incorrect': incorrect_certainties
#     })

#     # Set 'True Class' as the index
#     class_report.set_index('True Class', inplace=True)

#     # Sort the DataFrame by 'Certainty of Correct' in descending order
#     class_report['Sort Order'] = class_report['Certainty of Correct'].replace(0, -1)
#     class_report = class_report.sort_values(by=['Sort Order', 'Certainty of Incorrect'], ascending=[False, False])
#     class_report.drop('Sort Order', axis=1, inplace=True)

#     return class_report


# def most_predictions(y_pred_classes):
#     # Contar a frequência de cada classe predita
#     class_counts = np.bincount(y_pred_classes)

#     # Obter os índices das 5 classes mais frequentes
#     top_5_classes = np.argsort(class_counts)[-5:][::-1]

#     # Obter a contagem de vezes que cada uma das 5 classes foi predita
#     top_5_class_counts = class_counts[top_5_classes]

#     print("Top 5 classes more predicted:")
#     for class_id, count in zip(top_5_classes, top_5_class_counts):
#         print(f"Class {class_id}: {count} times")
#     return

# def no_predictions_or_incorrect(y_true, y_pred_classes):
#     # Count the frequency of each predicted class
#     class_counts = np.bincount(y_pred_classes)

#     # Find classes that have zero predictions
#     zero_pred_classes = np.where(class_counts == 0)[0]

#     # Count how many classes have no predictions
#     num_zero_pred_classes = len(zero_pred_classes)

#     # Check how many classes are not being predicted correctly (excluding zero-predicted classes)
#     incorrect_predictions_mask = y_true != y_pred_classes
#     incorrect_classes = np.unique(y_true[incorrect_predictions_mask])

#     # Filter out incorrect classes that are in zero_pred_classes
#     incorrect_classes = [cls for cls in incorrect_classes if cls not in zero_pred_classes]

#     # Print the results in the required format
#     print(f"{num_zero_pred_classes} classes are not being predicted at all: {zero_pred_classes}")
#     print(f"{len(incorrect_classes) } classes are not being predicted correctly: {incorrect_classes}")

#     return


# def certainties_averages(correct_certainties, incorrect_certainties):

#     # Filter out zeros from the correct and incorrect certainties
#     filtered_correct_certainties = [certainty for certainty in correct_certainties if certainty > 0]
#     filtered_incorrect_certainties = [certainty for certainty in incorrect_certainties if certainty > 0]

#     # Calculate the average percentage of certainty for correct and incorrect predictions, excluding zeros
#     average_correct_certainty = np.mean(filtered_correct_certainties) * 100  # Multiply by 100 to get percentage
#     average_incorrect_certainty = np.mean(filtered_incorrect_certainties) * 100  # Multiply by 100 to get percentage

#     # Print the results
#     print(f"Average Correct Certainty (excluding zeros): {average_correct_certainty:.2f}%")
#     print(f"Average Incorrect Certainty (excluding zeros): {average_incorrect_certainty:.2f}%")
    
#     return

# %% [markdown]
# <a class="anchor" id="nine-bullet">
# <d style="color:white;">
#
# ### 2.2. Sequential
# </a>
# </d>

# %% [markdown]
# **Baseline model**

# %%
model = Sequential(
    layers=[
        Input(shape=input_shape),
        # augmentation_layer, 
        Conv2D(filters=24, kernel_size=(3, 3), activation="relu"),  
        MaxPooling2D(pool_size=(2, 2)),
        Conv2D(filters=48, kernel_size=(3, 3), activation="relu"),
        MaxPooling2D(pool_size=(2, 2)),
        Flatten(),
        Dense(n_classes, activation="softmax"),
    ],
    name="sequential")

# %%
# Compile the model 
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=metrics
)

# %%
# Train the model
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=10,
    class_weight=class_weight_dict
)
# Out:
# Epoch 1/10
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 883s 838ms/step - accuracy: 0.0302 - f1_score: 0.0023 - loss: 5.5356 - precision: 0.0302 - recall: 0.0302 - val_accuracy: 0.0050 - val_f1_score: 4.9381e-05 - val_loss: 5.3571 - val_precision: 0.0050 - val_recall: 0.0050
# Epoch 2/10
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 801s 758ms/step - accuracy: 0.0363 - f1_score: 0.0102 - loss: 4.7523 - precision: 0.0363 - recall: 0.0363 - val_accuracy: 0.0046 - val_f1_score: 1.5978e-04 - val_loss: 5.3349 - val_precision: 0.0046 - val_recall: 0.0046
# Epoch 3/10
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 888s 849ms/step - accuracy: 0.0307 - f1_score: 0.0077 - loss: 4.9913 - precision: 0.0307 - recall: 0.0307 - val_accuracy: 0.0079 - val_f1_score: 0.0022 - val_loss: 5.3513 - val_precision: 0.0079 - val_recall: 0.0079
# Epoch 4/10
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 1025s 975ms/step - accuracy: 0.0226 - f1_score: 0.0063 - loss: 4.9799 - precision: 0.0226 - recall: 0.0226 - val_accuracy: 0.0071 - val_f1_score: 0.0011 - val_loss: 5.3856 - val_precision: 0.0071 - val_recall: 0.0071
# Epoch 5/10
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 909s 857ms/step - accuracy: 0.0229 - f1_score: 0.0125 - loss: 4.9227 - precision: 0.0229 - recall: 0.0229 - val_accuracy: 0.0188 - val_f1_score: 0.0039 - val_loss: 6.2340 - val_precision: 0.0188 - val_recall: 0.0188
# Epoch 6/10
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 1053s 1s/step - accuracy: 0.0697 - f1_score: 0.0353 - loss: 4.6580 - precision: 0.0697 - recall: 0.0697 - val_accuracy: 0.0188 - val_f1_score: 0.0042 - val_loss: 7.2558 - val_precision: 0.0188 - val_recall: 0.0188
# Epoch 7/10
#  141/1042 ━━━━━━━━━━━━━━━━━━━━ 7:53 526ms/step - accuracy: 0.0389 - f1_score: 0.0026 - loss: 4.9391 - precision: 0.0389 - recall: 0.0389

# %%
results = model.evaluate(
    test_dataset,
    return_dict=True,
    verbose=0 
)

print("Test set results:")
for metric_name, value in results.items():
    print(f"{metric_name}: {value:.4f}")
# Out:
# Test set results:
# accuracy: 0.0233
# f1_score: 0.0155
# loss: 7.9670
# precision: 0.0233
# recall: 0.0233

# %% [markdown]
# **Bayesian search**

# %%
# # Global variable to track best F1 across all trials
# best_f1 = 0.0

# # Sweep configuration for W&B
# sweep_config = {
#     'method': 'bayes',  # Bayesian optimization
#     'name': 'SequentialModelSweep',
#     'metric': {
#         'name': 'val_f1_score',
#         'goal': 'maximize'
#     },
#     'parameters': {
#         'filters_1': {'values': [16, 32, 48, 64]},
#         'filters_2': {'values': [32, 64, 96, 128]},
#         'kernel_size': {'values': ['3x3', '5x5']},
#         'learning_rate': {'min': 1e-4, 'max': 1e-2},
#         'use_augmentation': {'values': [True, False]},
#         'activation': {'values': ['relu', 'leaky_relu']},
#         'optimizer': {'values': ['adam', 'rmsprop']},
#     }
# }

# # Initialize sweep
# sweep_id = wandb.sweep(sweep_config, project="dl_project")

# # Training function
# def train_model(config=None):
#     with wandb.init(config=config):
#         config = wandb.config

#         model = Sequential()
#         model.add(Input(shape=input_shape))

#         if config.use_augmentation:
#             model.add(augmentation_layer)

#         kernel_size = tuple(map(int, config.kernel_size.split("x")))
#         model.add(Conv2D(config.filters_1, kernel_size=kernel_size))
#         model.add(LeakyReLU() if config.activation == "leaky_relu" else tf.keras.layers.Activation(config.activation))
#         model.add(MaxPooling2D(pool_size=(2, 2)))

#         model.add(Conv2D(config.filters_2, kernel_size=kernel_size))
#         model.add(LeakyReLU() if config.activation == "leaky_relu" else tf.keras.layers.Activation(config.activation))
#         model.add(MaxPooling2D(pool_size=(2, 2)))

#         model.add(Flatten())
#         model.add(Dense(n_classes, activation="softmax"))

#         optimizer = Adam(learning_rate=config.learning_rate) if config.optimizer == "adam" else RMSprop(learning_rate=config.learning_rate)

#         model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=metrics)

#         early_stopping = EarlyStopping(monitor="val_f1_score", patience=3, restore_best_weights=True, mode="max")
#         wandb_callback = WandbCallback(save_graph=False, save_model=False)

#         history = model.fit(
#             train_dataset,
#             validation_data=val_dataset,
#             epochs=5,
#             class_weight=class_weight_dict,
#             callbacks=[early_stopping, wandb_callback]
#         )

#         # Save best model if this trial achieved a better f1
#         global best_f1
#         val_f1_scores = history.history.get("val_f1_score")
#         if val_f1_scores:
#             trial_best = max(val_f1_scores)
#             if trial_best > best_f1:
#                 best_f1 = trial_best
#                 model.save("best_model.keras")
#                 print(f"\n Saved new best model with val_f1_score = {best_f1:.4f}")

# # Run the sweep
# wandb.agent(sweep_id, function=train_model, count=50)

# %%
# # check best model parameters
# api = wandb.Api()
# sweep = api.sweep("matildestreet-nova-ims/dl_project/4xk38eju")
# runs = sweep.runs
# best_run = max(runs, key=lambda r: r.summary.get("val_f1_score", 0))

# print("Best run config:")
# for key, value in best_run.config.items():
#     print(f"{key}: {value}")



# # output - best was trial 49
# Best run config:
# filters_1: 32
# filters_2: 32
# optimizer: rmsprop
# activation: leaky_relu
# kernel_size: 5x5
# learning_rate: 0.001526590318714996
# use_augmentation: False

# %%
best_model = Sequential(
    layers=[
        Input(shape=input_shape),
        Conv2D(filters=32, kernel_size=(5, 5), activation="leaky_relu"),  
        MaxPooling2D(pool_size=(2, 2)),
        Conv2D(filters=32, kernel_size=(5, 5), activation="leaky_relu"),
        MaxPooling2D(pool_size=(2, 2)),
        Flatten(),
        Dense(n_classes, activation="softmax"),
    ],
    name="sequential"
)

# %%
# Compile with best optimizer and learning rate
optimizer = RMSprop(learning_rate=0.001526590318714996)

# Compile the model 
best_model.compile(
    optimizer=optimizer,
    loss=CategoricalCrossentropy(),
    metrics=metrics
)

# %%
early_stop = EarlyStopping(
    monitor='val_f1_score',   # nome da métrica que defines (ver abaixo)
    mode='max',
    patience=5,
    restore_best_weights=True,
    verbose=1
)

# %%
# Train the model
history = best_model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs= 50,
    class_weight=class_weight_dict,
    callbacks=[early_stop])
# Out:
# Epoch 1/50
#  56/216 ━━━━━━━━━━━━━━━━━━━━ 2:50 1s/step - accuracy: 0.2193 - f1_score: 0.0126 - loss: 12.3761 - precision: 0.2193 - recall: 0.2193
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10364\2593016992.py in ?()
#       1 # Train the model
# ----> 2 history = best_model.fit(
#       3     train_dataset,
#       4     validation_data=val_dataset,
#       5     epochs= 50,
#
# c:\Users\joana\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# c:\Users\joana\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py in ?(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     368             with epoch_iterator.catch_stop_iteration():
#     369                 for step, iterator in epoch_iterator:
#     370                     callbacks.on_train_batch_begin(step)
#     371                     logs = self.train_function(iterator)
# --> 372                     callbacks.on_train_batch_end(step, logs)
#     373                     if self.stop_training:
#     374                         break
#     375
#
# c:\Users\joana\anaconda3\Lib\site-packages\keras\src\callbacks\callback_list.py in ?(self, batch, logs)
#     168     def on_train_batch_end(self, batch, logs=None):
#     169         if self._async_train:
#     170             self._async_dispatch(self._on_train_batch_end, batch, logs)
#     171         else:
# --> 172             self._on_train_batch_end(batch, logs)
#
# c:\Users\joana\anaconda3\Lib\site-packages\keras\src\callbacks\callback_list.py in ?(self, batch, logs)
#     191     def _on_train_batch_end(self, batch, logs=None):
#     192         logs = python_utils.pythonify_logs(logs)
#     193         for callback in self.callbacks:
# --> 194             callback.on_train_batch_end(batch, logs=logs)
#
# c:\Users\joana\anaconda3\Lib\site-packages\keras\src\callbacks\progbar_logger.py in ?(self, batch, logs)
#      57     def on_train_batch_end(self, batch, logs=None):
# ---> 58         self._update_progbar(batch, logs)
#
# c:\Users\joana\anaconda3\Lib\site-packages\keras\src\callbacks\progbar_logger.py in ?(self, batch, logs)
#      91         self._maybe_init_progbar()
#      92         self.seen = batch + 1  # One-indexed.
#      93
#      94         if self.verbose == 1:
# ---> 95             self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# c:\Users\joana\anaconda3\Lib\site-packages\keras\src\utils\progbar.py in ?(self, current, values, finalize)
#     159             for k in self._values_order:
#     160                 info += f" - {k}:"
#     161                 if isinstance(self._values[k], list):
#     162                     avg = backend.convert_to_numpy(
# --> 163                         backend.numpy.mean(
#     164                             self._values[k][0] / max(1, self._values[k][1])
#     165                         )
#     166                     )
#
# c:\Users\joana\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\numpy.py in ?(x, axis, keepdims)
#     662     if "int" in ori_dtype or ori_dtype == "bool":
#     663         result_dtype = compute_dtype
#     664     else:
#     665         result_dtype = ori_dtype
# --> 666     output = tf.reduce_mean(
#     667         tf.cast(x, compute_dtype), axis=axis, keepdims=keepdims
#     668     )
#     669     return tf.cast(output, result_dtype)
#
# c:\Users\joana\anaconda3\Lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py in ?(*args, **kwargs)
#      86   def wrapper(*args, **kwargs):
#      87     if not ops.is_auto_dtype_conversion_enabled():
# ---> 88       return op(*args, **kwargs)
#      89     bound_arguments = signature.bind(*args, **kwargs)
#      90     bound_arguments.apply_defaults()
#      91     bound_kwargs = bound_arguments.arguments
#
# c:\Users\joana\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\Users\joana\anaconda3\Lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# c:\Users\joana\anaconda3\Lib\site-packages\tensorflow\python\ops\math_ops.py in ?(input_tensor, axis, keepdims, name)
#    2589   """
#    2590   keepdims = False if keepdims is None else bool(keepdims)
#    2591   return _may_reduce_to_scalar(
#    2592       keepdims, axis,
# -> 2593       gen_math_ops.mean(
#    2594           input_tensor, _ReductionDims(input_tensor, axis), keepdims,
#    2595           name=name))
#
# c:\Users\joana\anaconda3\Lib\site-packages\tensorflow\python\ops\gen_math_ops.py in ?(input, axis, keep_dims, name)
#    6510         _ctx, "Mean", name, input, axis, "keep_dims", keep_dims)
#    6511       return _result
#    6512     except _core._NotOkStatusException as e:
#    6513       _ops.raise_from_not_ok_status(e, name)
# -> 6514     except _core._FallbackException:
#    6515       pass
#    6516     try:
#    6517       return mean_eager_fallback(
#
# KeyboardInterrupt:

# %%
results = best_model.evaluate(
    test_dataset,
    return_dict=True,
    verbose=0 
)

print("Test set results:")
for metric_name, value in results.items():
    print(f"{metric_name}: {value:.4f}")
# Out:
# Test set results:
# accuracy: 0.0337
# f1_score: 0.0261
# loss: 18.8094
# precision: 0.0337
# recall: 0.0337

# %% [markdown]
# the f1 score is higher after the bayesian optimization, however the difference is not that big and the loss is much higher

# %% [markdown]
# Trying with the dataaugmentation to see if the score gets better

# %%
# Train the model
history = best_model.fit(
    train_dataset_aug,
    validation_data=val_dataset,
    epochs=10,
    class_weight=class_weight_dict
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Train the model
# ----> 2 history = best_model.fit(
#       3     train_dataset_aug,
#       4     validation_data=val_dataset,
#       5     epochs=10,
#       6     class_weight=class_weight_dict
#       7 )
#
# NameError: name 'best_model' is not defined

# %%
results = best_model.evaluate(
    test_dataset,
    return_dict=True,
    verbose=0 
)

print("Test set results:")
for metric_name, value in results.items():
    print(f"{metric_name}: {value:.4f}")
# Out:
# Test set results:
# accuracy: 0.0079
# f1_score: 0.0101
# loss: 21.7057
# precision: 0.0079
# recall: 0.0079

# %% [markdown]
# **Baseline model**

# %%
def functional_model():
    conv_layer_1 = layers.Conv2D(
        filters=3 * 8,
        kernel_size=(3, 3),
        activation="relu",
        name="conv_layer_1"
    )
    max_pool_layer_1 = layers.MaxPooling2D(pool_size=(2, 2), name="max_pool_layer_1")

    conv_layer_2 = layers.Conv2D(
        filters=3 * 16,
        kernel_size=(3, 3),
        name="conv_layer_2"
    )
    act_layer_2 = layers.LeakyReLU(negative_slope=0.3, name="act_layer_2")
    max_pool_layer_2 = layers.MaxPooling2D(pool_size=(2, 2), name="max_pool_layer_2")

    flatten_layer = layers.Flatten(name="flatten_layer")
    dense_layer = layers.Dense(
        n_classes,
        activation="softmax",
        name="classification_head"
    )

    inputs = layers.Input(shape=input_shape)
    x = inputs

    x = conv_layer_1(x)
    x = max_pool_layer_1(x)

    x = conv_layer_2(x)
    x = act_layer_2(x)
    x = max_pool_layer_2(x)

    x = flatten_layer(x)
    x = dense_layer(x)

    outputs = x

    return models.Model(inputs=inputs, outputs=outputs, name="my_tiny_functional_cnn")

# %%
# Compile the model
model=functional_model()
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=metrics)

# %%
# Train the model
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=10)
# Out:
# Epoch 1/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 47s 214ms/step - accuracy: 0.0300 - f1_score: 0.0140 - loss: 6.3319 - precision: 0.0300 - recall: 0.0300 - val_accuracy: 0.0100 - val_f1_score: 9.8314e-05 - val_loss: 7.5576 - val_precision: 0.0100 - val_recall: 0.0100
# Epoch 2/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 45s 210ms/step - accuracy: 0.0312 - f1_score: 0.0037 - loss: 5.6284 - precision: 0.0312 - recall: 0.0312 - val_accuracy: 0.0075 - val_f1_score: 7.3919e-05 - val_loss: 11.3704 - val_precision: 0.0075 - val_recall: 0.0075
# Epoch 3/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 45s 209ms/step - accuracy: 0.0291 - f1_score: 0.0053 - loss: 5.3975 - precision: 0.0291 - recall: 0.0291 - val_accuracy: 0.0092 - val_f1_score: 0.0018 - val_loss: 8.5347 - val_precision: 0.0092 - val_recall: 0.0092
# Epoch 4/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 45s 209ms/step - accuracy: 0.0436 - f1_score: 0.0144 - loss: 4.9761 - precision: 0.0436 - recall: 0.0436 - val_accuracy: 0.0171 - val_f1_score: 0.0060 - val_loss: 9.9364 - val_precision: 0.0171 - val_recall: 0.0171
# Epoch 5/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 45s 209ms/step - accuracy: 0.0956 - f1_score: 0.0370 - loss: 4.4388 - precision: 0.0956 - recall: 0.0956 - val_accuracy: 0.0184 - val_f1_score: 0.0109 - val_loss: 13.4726 - val_precision: 0.0184 - val_recall: 0.0184
# Epoch 6/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 45s 209ms/step - accuracy: 0.1945 - f1_score: 0.0711 - loss: 4.1559 - precision: 0.1945 - recall: 0.1945 - val_accuracy: 0.0305 - val_f1_score: 0.0123 - val_loss: 30.4469 - val_precision: 0.0305 - val_recall: 0.0305
# Epoch 7/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 45s 209ms/step - accuracy: 0.2136 - f1_score: 0.1137 - loss: 4.0831 - precision: 0.2136 - recall: 0.2136 - val_accuracy: 0.0280 - val_f1_score: 0.0176 - val_loss: 10.3867 - val_precision: 0.0280 - val_recall: 0.0280
# Epoch 8/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 45s 209ms/step - accuracy: 0.3331 - f1_score: 0.1992 - loss: 2.9801 - precision: 0.3331 - recall: 0.3331 - val_accuracy: 0.0347 - val_f1_score: 0.0191 - val_loss: 16.0878 - val_precision: 0.0347 - val_recall: 0.0347
# Epoch 9/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 45s 209ms/step - accuracy: 0.4115 - f1_score: 0.2477 - loss: 2.7617 - precision: 0.4115 - recall: 0.4115 - val_accuracy: 0.0397 - val_f1_score: 0.0201 - val_loss: 13.2728 - val_precision: 0.0397 - val_recall: 0.0397
# Epoch 10/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 45s 208ms/step - accuracy: 0.5261 - f1_score: 0.3038 - loss: 2.1795 - precision: 0.5261 - recall: 0.5261 - val_accuracy: 0.0439 - val_f1_score: 0.0253 - val_loss: 12.8788 - val_precision: 0.0439 - val_recall: 0.0439

# %%
results = model.evaluate(
    test_dataset,
    return_dict=True,
    verbose=0
)

print("Test set results:")
for metric_name, value in results.items():
    print(f"{metric_name}: {value:.4f}")
# Out:
# Test set results:
# accuracy: 0.0283
# f1_score: 0.0232
# loss: 13.1315
# precision: 0.0283
# recall: 0.0283

# %% [markdown]
# **Bayesian search**

# %%
# # Sweep configuration
# sweep_config = {
#     'method': 'bayes',
#     'name': 'FunctionalModelSweep',
#     'metric': {
#         'name': 'val_f1_score',
#         'goal': 'maximize'
#     },
#     'parameters': {
#         'filters_1': {'values': [16, 32, 48, 64]},
#         'filters_2': {'values': [32, 64, 96, 128]},
#         'kernel_size': {'values': ['3x3', '5x5']},
#         'learning_rate': {'min': 1e-4, 'max': 1e-2},
#         'use_augmentation': {'values': [True, False]},
#         'activation': {'values': ['relu', 'leaky_relu']},
#         'alpha': {'min': 0.1, 'max': 0.5},  # for LeakyReLU
#         'optimizer': {'values': ['adam', 'rmsprop']},
#     }
# }

# sweep_id = wandb.sweep(sweep_config, project="dl_project")

# # Training function
# def train_model(config=None):
#     with wandb.init(config=config):
#         config = wandb.config

#         # Layers
#         conv1 = layers.Conv2D(filters=config.filters_1, kernel_size=tuple(map(int, config.kernel_size.split('x'))), name='conv_1')
#         conv2 = layers.Conv2D(filters=config.filters_2, kernel_size=tuple(map(int, config.kernel_size.split('x'))), name='conv_2')
#         maxpool = layers.MaxPooling2D(pool_size=(2, 2))

#         activation_1 = layers.Activation('relu') if config.activation == "relu" else layers.LeakyReLU(alpha=config.alpha)
#         activation_2 = layers.Activation('relu') if config.activation == "relu" else layers.LeakyReLU(alpha=config.alpha)

#         flatten = layers.Flatten()
#         dense = layers.Dense(n_classes, activation='softmax', name='output')

#         inputs = layers.Input(shape=input_shape)
#         x = inputs

#         if config.use_augmentation:
#             x = augmentation_layer(x)

#         x = conv1(x)
#         x = maxpool(x)

#         x = conv2(x)
#         x = activation_2(x)
#         x = maxpool(x)

#         x = flatten(x)
#         outputs = dense(x)

#         model = models.Model(inputs=inputs, outputs=outputs)

#         optimizer = Adam(learning_rate=config.learning_rate) if config.optimizer == "adam" else RMSprop(learning_rate=config.learning_rate)
#         model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=metrics)

#         early_stopping = EarlyStopping(monitor='val_f1_score', patience=3, restore_best_weights=True, mode='max')

#         model.fit(
#             train_dataset,
#             validation_data=val_dataset,
#             epochs=10,
#             class_weight=class_weight_dict,
#             callbacks=[early_stopping, WandbCallback(save_model=False, save_graph=False)],
#             verbose=1
#         )

# # Start sweep
# wandb.agent(sweep_id, function=train_model, count=50)

# %%
# # Load W&B API and fetch sweep by project path and sweep ID
# api = wandb.Api()
# sweep = api.sweep("matildestreet-nova-ims/dl_project/7jkmks1l")  
# runs = sweep.runs

# # Get the run with the highest validation F1 score
# best_run = max(runs, key=lambda r: r.summary.get("val_f1_score", 0))

# # Print the configuration of the best run
# print("Best run config:")
# for key, value in best_run.config.items():
#     print(f"{key}: {value}")



# # output
# Best run config:
# alpha: 0.48096970546631235
# filters_1: 64
# filters_2: 32
# optimizer: rmsprop
# activation: leaky_relu
# kernel_size: 3x3
# learning_rate: 0.0005838087914898498
# use_augmentation: False

# %%
# Define the functional model with best parameters
def best_functional_model():
    inputs = layers.Input(shape=input_shape, name="input")

    # Conv layer 1
    x = layers.Conv2D(64, kernel_size=(3, 3), activation=None, name="conv_1")(inputs)
    x = layers.LeakyReLU(alpha=0.48, name="leaky_relu_1")(x)
    x = layers.MaxPooling2D(pool_size=(2, 2), name="max_pool_1")(x)

    # Conv layer 2
    x = layers.Conv2D(32, kernel_size=(3, 3), activation=None, name="conv_2")(x)
    x = layers.LeakyReLU(alpha=0.48, name="leaky_relu_2")(x)
    x = layers.MaxPooling2D(pool_size=(2, 2), name="max_pool_2")(x)

    # Flatten + classification head
    x = layers.Flatten(name="flatten")(x)
    outputs = layers.Dense(n_classes, activation="softmax", name="output")(x)

    model = models.Model(inputs=inputs, outputs=outputs, name="best_functional_model")
    return model

# Instantiate and compile the model
best_model = best_functional_model()
optimizer = optimizers.RMSprop(learning_rate=0.0005838087914898498)

best_model.compile(
    optimizer=optimizer,
    loss=CategoricalCrossentropy(),
    metrics=metrics  
)

# Train the model (sem class_weight)
history = best_model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=10
)
# Out:
# c:\USERS\PAULO\ANACONDA3\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 3:45 1s/step - accuracy: 0.0312 - f1_score: 0.0135 - loss: 5.5261 - precision: 0.0312 - recall: 0.031 ━━━━━━━━━━━━━━━━━━━━ 1:03 299ms/step - accuracy: 0.0375 - f1_score: 0.0138 - loss: 4.1446 - precision: 0.0375 - recall: 0.03 ━━━━━━━━━━━━━━━━━━━━ 1:04 304ms/step - accuracy: 0.0426 - f1_score: 0.0140 - loss: 3.8233 - precision: 0.0426 - recall: 0.04 ━━━━━━━━━━━━━━━━━━━━ 1:03 303ms/step - accuracy: 0.0460 - f1_score: 0.0144 - loss: 3.8495 - precision: 0.0460 - recall: 0.04 ━━━━━━━━━━━━━━━━━━━━ 1:04 306ms/step - accuracy: 0.0503 - f1_score: 0.0152 - loss: 3.7741 - precision: 0.0503 - recall: 0.05 ━━━━━━━━━━━━━━━━━━━━ 1:02 300ms/step - accuracy: 0.0531 - f1_score: 0.0156 - loss: 3.9943 - precision: 0.0531 - recall: 0.05 ━━━━━━━━━━━━━━━━━━━━ 1:02 300ms/step - accuracy: 0.0550 - f1_score: 0.0159 - loss: 4.1693 - precision: 0.0550 - recall: 0.05 ━━━━━━━━━━━━━━━━━━━━ 1:02 304ms/step - accuracy: 0.0565 - f1_score: 0.0162 - loss: 4.2824 - precision: 0.0565 - recall: 0.05 ━━━━━━━━━━━━━━━━━━━━ 1:03 308ms/step - accuracy: 0.0588 - f1_score: 0.0165 - loss: 4.3107 - precision: 0.0588 - recall: 0.05 ━━━━━━━━━━━━━━━━━━━━ 1:03 308ms/step - accuracy: 0.0608 - f1_score: 0.0168 - loss: 4.3589 - precision: 0.0608 - recall: 0.06 ━━━━━━━━━━━━━━━━━━━━ 1:02 307ms/step - accuracy: 0.0624 - f1_score: 0.0171 - loss: 4.3899 - precision: 0.0624 - recall: 0.06 ━━━━━━━━━━━━━━━━━━━━ 1:01 304ms/step - accuracy: 0.0637 - f1_score: 0.0173 - loss: 4.4216 - precision: 0.0637 - recall: 0.06 ━━━━━━━━━━━━━━━━━━━━ 1:00 302ms/step - accuracy: 0.0649 - f1_score: 0.0176 - loss: 4.4470 - precision: 0.0649 - recall: 0.06 ━━━━━━━━━━━━━━━━━━━━ 1:00 303ms/step - accuracy: 0.0658 - f1_score: 0.0179 - loss: 4.4697 - precision: 0.0658 - recall: 0.06 ━━━━━━━━━━━━━━━━━━━━ 1:00 302ms/step - accuracy: 0.0666 - f1_score: 0.0181 - loss: 4.4906 - precision: 0.0666 - recall: 0.06 ━━━━━━━━━━━━━━━━━━━━ 1:01 308ms/step - accuracy: 0.0672 - f1_score: 0.0182 - loss: 4.5116 - precision: 0.0672 - recall: 0.06 ━━━━━━━━━━━━━━━━━━━━ 1:01 309ms/step - accuracy: 0.0678 - f1_score: 0.0185 - loss: 4.5314 - precision: 0.0678 - recall: 0.06 ━━━━━━━━━━━━━━━━━━━━ 1:00 307ms/step - accuracy: 0.0683 - f1_score: 0.0186 - loss: 4.5492 - precision: 0.0683 - recall: 0.06 ━━━━━━━━━━━━━━━━━━━━ 59s 305ms/step - accuracy: 0.0686 - f1_score: 0.0188 - loss: 4.5620 - precision: 0.0686 - recall: 0.0686 ━━━━━━━━━━━━━━━━━━━━ 59s 305ms/step - accuracy: 0.0692 - f1_score: 0.0190 - loss: 4.5766 - precision: 0.0692 - recall: 0.069 ━━━━━━━━━━━━━━━━━━━━ 59s 305ms/step - accuracy: 0.0696 - f1_score: 0.0192 - loss: 4.5910 - precision: 0.0696 - recall: 0.069 ━━━━━━━━━━━━━━━━━━━━ 58s 304ms/step - accuracy: 0.0701 - f1_score: 0.0193 - loss: 4.6056 - precision: 0.0701 - recall: 0.070 ━━━━━━━━━━━━━━━━━━━━ 58s 303ms/step - accuracy: 0.0704 - f1_score: 0.0195 - loss: 4.6187 - precision: 0.0704 - recall: 0.070 ━━━━━━━━━━━━━━━━━━━━ 57s 302ms/step - accuracy: 0.0707 - f1_score: 0.0196 - loss: 4.6297 - precision: 0.0707 - recall: 0.070 ━━━━━━━━━━━━━━━━━━━━ 57s 301ms/step - accuracy: 0.0709 - f1_score: 0.0197 - loss: 4.6404 - precision: 0.0709 - recall: 0.070 ━━━━━━━━━━━━━━━━━━━━ 56s 299ms/step - accuracy: 0.0712 - f1_score: 0.0198 - loss: 4.6506 - precision: 0.0712 - recall: 0.071 ━━━━━━━━━━━━━━━━━━━━ 56s 298ms/step - accuracy: 0.0713 - f1_score: 0.0199 - loss: 4.6604 - precision: 0.0713 - recall: 0.071 ━━━━━━━━━━━━━━━━━━━━ 55s 297ms/step - accuracy: 0.0715 - f1_score: 0.0200 - loss: 4.6699 - precision: 0.0715 - recall: 0.071 ━━━━━━━━━━━━━━━━━━━━ 55s 297ms/step - accuracy: 0.0716 - f1_score: 0.0201 - loss: 4.6787 - precision: 0.0716 - recall: 0.071 ━━━━━━━━━━━━━━━━━━━━ 54s 297ms/step - accuracy: 0.0717 - f1_score: 0.0202 - loss: 4.6870 - precision: 0.0717 - recall: 0.071 ━━━━━━━━━━━━━━━━━━━━ 54s 296ms/step - accuracy: 0.0718 - f1_score: 0.0203 - loss: 4.6949 - precision: 0.0718 - recall: 0.071 ━━━━━━━━━━━━━━━━━━━━ 54s 296ms/step - accuracy: 0.0719 - f1_score: 0.0204 - loss: 4.7013 - precision: 0.0719 - recall: ...
# Epoch 2/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 1:25 402ms/step - accuracy: 0.0000e+00 - f1_score: 0.0000e+00 - loss: 8.6426 - precision: 0.0000e+00 - recall: 0.0000e+ ━━━━━━━━━━━━━━━━━━━━ 1:01 287ms/step - accuracy: 0.2500 - f1_score: 0.0017 - loss: 7.2373 - precision: 0.2500 - recall: 0.2500               ━━━━━━━━━━━━━━━━━━━━ 1:01 288ms/step - accuracy: 0.3611 - f1_score: 0.0023 - loss: 6.3283 - precision: 0.3611 - recall: 0.36 ━━━━━━━━━━━━━━━━━━━━ 1:00 286ms/step - accuracy: 0.3802 - f1_score: 0.0025 - loss: 5.9687 - precision: 0.3802 - recall: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:00 288ms/step - accuracy: 0.3742 - f1_score: 0.0026 - loss: 5.7004 - precision: 0.3742 - recall: 0.37 ━━━━━━━━━━━━━━━━━━━━ 1:00 289ms/step - accuracy: 0.3604 - f1_score: 0.0026 - loss: 5.4866 - precision: 0.3604 - recall: 0.36 ━━━━━━━━━━━━━━━━━━━━ 1:00 293ms/step - accuracy: 0.3459 - f1_score: 0.0027 - loss: 5.3681 - precision: 0.3459 - recall: 0.34 ━━━━━━━━━━━━━━━━━━━━ 1:00 295ms/step - accuracy: 0.3320 - f1_score: 0.0028 - loss: 5.2624 - precision: 0.3320 - recall: 0.33 ━━━━━━━━━━━━━━━━━━━━ 59s 290ms/step - accuracy: 0.3306 - f1_score: 0.0032 - loss: 5.1312 - precision: 0.3306 - recall: 0.3306 ━━━━━━━━━━━━━━━━━━━━ 58s 287ms/step - accuracy: 0.3275 - f1_score: 0.0035 - loss: 5.0485 - precision: 0.3275 - recall: 0.327 ━━━━━━━━━━━━━━━━━━━━ 58s 285ms/step - accuracy: 0.3246 - f1_score: 0.0038 - loss: 4.9698 - precision: 0.3246 - recall: 0.324 ━━━━━━━━━━━━━━━━━━━━ 57s 284ms/step - accuracy: 0.3201 - f1_score: 0.0040 - loss: 4.8977 - precision: 0.3201 - recall: 0.320 ━━━━━━━━━━━━━━━━━━━━ 57s 284ms/step - accuracy: 0.3160 - f1_score: 0.0045 - loss: 4.8415 - precision: 0.3160 - recall: 0.316 ━━━━━━━━━━━━━━━━━━━━ 57s 287ms/step - accuracy: 0.3112 - f1_score: 0.0048 - loss: 4.7941 - precision: 0.3112 - recall: 0.311 ━━━━━━━━━━━━━━━━━━━━ 57s 287ms/step - accuracy: 0.3058 - f1_score: 0.0050 - loss: 4.7531 - precision: 0.3058 - recall: 0.305 ━━━━━━━━━━━━━━━━━━━━ 57s 291ms/step - accuracy: 0.3003 - f1_score: 0.0053 - loss: 4.7201 - precision: 0.3003 - recall: 0.300 ━━━━━━━━━━━━━━━━━━━━ 57s 291ms/step - accuracy: 0.2951 - f1_score: 0.0055 - loss: 4.6919 - precision: 0.2951 - recall: 0.295 ━━━━━━━━━━━━━━━━━━━━ 57s 290ms/step - accuracy: 0.2905 - f1_score: 0.0059 - loss: 4.6669 - precision: 0.2905 - recall: 0.290 ━━━━━━━━━━━━━━━━━━━━ 56s 289ms/step - accuracy: 0.2859 - f1_score: 0.0061 - loss: 4.6413 - precision: 0.2859 - recall: 0.285 ━━━━━━━━━━━━━━━━━━━━ 56s 290ms/step - accuracy: 0.2824 - f1_score: 0.0064 - loss: 4.6196 - precision: 0.2824 - recall: 0.282 ━━━━━━━━━━━━━━━━━━━━ 56s 291ms/step - accuracy: 0.2799 - f1_score: 0.0068 - loss: 4.5966 - precision: 0.2799 - recall: 0.279 ━━━━━━━━━━━━━━━━━━━━ 56s 290ms/step - accuracy: 0.2774 - f1_score: 0.0071 - loss: 4.5798 - precision: 0.2774 - recall: 0.277 ━━━━━━━━━━━━━━━━━━━━ 55s 290ms/step - accuracy: 0.2747 - f1_score: 0.0074 - loss: 4.5647 - precision: 0.2747 - recall: 0.274 ━━━━━━━━━━━━━━━━━━━━ 55s 290ms/step - accuracy: 0.2722 - f1_score: 0.0078 - loss: 4.5484 - precision: 0.2722 - recall: 0.272 ━━━━━━━━━━━━━━━━━━━━ 55s 290ms/step - accuracy: 0.2696 - f1_score: 0.0081 - loss: 4.5368 - precision: 0.2696 - recall: 0.269 ━━━━━━━━━━━━━━━━━━━━ 54s 289ms/step - accuracy: 0.2668 - f1_score: 0.0083 - loss: 4.5264 - precision: 0.2668 - recall: 0.266 ━━━━━━━━━━━━━━━━━━━━ 54s 289ms/step - accuracy: 0.2640 - f1_score: 0.0086 - loss: 4.5169 - precision: 0.2640 - recall: 0.264 ━━━━━━━━━━━━━━━━━━━━ 53s 289ms/step - accuracy: 0.2612 - f1_score: 0.0088 - loss: 4.5082 - precision: 0.2612 - recall: 0.261 ━━━━━━━━━━━━━━━━━━━━ 53s 288ms/step - accuracy: 0.2586 - f1_score: 0.0090 - loss: 4.4999 - precision: 0.2586 - recall: 0.258 ━━━━━━━━━━━━━━━━━━━━ 53s 287ms/step - accuracy: 0.2559 - f1_score: 0.0093 - loss: 4.4918 - precision: 0.2559 - recall: 0.255 ━━━━━━━━━━━━━━━━━━━━ 52s 287ms/step - accuracy: 0.2532 - f1_score: 0.0095 - loss: 4.4844 - precision: 0.2532 - recall: 0.253 ━━━━━━━━━━━━━━━━━━━━ 52s 287ms/step - accuracy: 0.2506 - f1_score: 0.0097 - loss: 4. ...
# Epoch 3/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 1:30 423ms/step - accuracy: 0.0000e+00 - f1_score: 0.0000e+00 - loss: 5.9836 - precision: 0.0000e+00 - recall: 0.0000e+ ━━━━━━━━━━━━━━━━━━━━ 1:03 296ms/step - accuracy: 0.2500 - f1_score: 0.0017 - loss: 4.8820 - precision: 0.2500 - recall: 0.2500               ━━━━━━━━━━━━━━━━━━━━ 1:01 289ms/step - accuracy: 0.3611 - f1_score: 0.0023 - loss: 4.2049 - precision: 0.3611 - recall: 0.36 ━━━━━━━━━━━━━━━━━━━━ 1:00 286ms/step - accuracy: 0.3978 - f1_score: 0.0032 - loss: 3.9207 - precision: 0.3978 - recall: 0.39 ━━━━━━━━━━━━━━━━━━━━ 59s 285ms/step - accuracy: 0.4195 - f1_score: 0.0042 - loss: 3.7114 - precision: 0.4195 - recall: 0.4195 ━━━━━━━━━━━━━━━━━━━━ 59s 283ms/step - accuracy: 0.4199 - f1_score: 0.0047 - loss: 3.6200 - precision: 0.4199 - recall: 0.419 ━━━━━━━━━━━━━━━━━━━━ 59s 285ms/step - accuracy: 0.4128 - f1_score: 0.0051 - loss: 3.5752 - precision: 0.4128 - recall: 0.412 ━━━━━━━━━━━━━━━━━━━━ 59s 287ms/step - accuracy: 0.4159 - f1_score: 0.0058 - loss: 3.5179 - precision: 0.4159 - recall: 0.415 ━━━━━━━━━━━━━━━━━━━━ 59s 287ms/step - accuracy: 0.4253 - f1_score: 0.0065 - loss: 3.4352 - precision: 0.4253 - recall: 0.425 ━━━━━━━━━━━━━━━━━━━━ 58s 287ms/step - accuracy: 0.4290 - f1_score: 0.0070 - loss: 3.3994 - precision: 0.4290 - recall: 0.429 ━━━━━━━━━━━━━━━━━━━━ 59s 290ms/step - accuracy: 0.4329 - f1_score: 0.0076 - loss: 3.3629 - precision: 0.4329 - recall: 0.432 ━━━━━━━━━━━━━━━━━━━━ 58s 291ms/step - accuracy: 0.4328 - f1_score: 0.0081 - loss: 3.3334 - precision: 0.4328 - recall: 0.432 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.4315 - f1_score: 0.0086 - loss: 3.3171 - precision: 0.4315 - recall: 0.431 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.4287 - f1_score: 0.0092 - loss: 3.3066 - precision: 0.4287 - recall: 0.428 ━━━━━━━━━━━━━━━━━━━━ 58s 294ms/step - accuracy: 0.4247 - f1_score: 0.0096 - loss: 3.2990 - precision: 0.4247 - recall: 0.424 ━━━━━━━━━━━━━━━━━━━━ 59s 298ms/step - accuracy: 0.4198 - f1_score: 0.0100 - loss: 3.2967 - precision: 0.4198 - recall: 0.419 ━━━━━━━━━━━━━━━━━━━━ 59s 299ms/step - accuracy: 0.4148 - f1_score: 0.0104 - loss: 3.2957 - precision: 0.4148 - recall: 0.414 ━━━━━━━━━━━━━━━━━━━━ 59s 300ms/step - accuracy: 0.4102 - f1_score: 0.0108 - loss: 3.2949 - precision: 0.4102 - recall: 0.410 ━━━━━━━━━━━━━━━━━━━━ 59s 301ms/step - accuracy: 0.4061 - f1_score: 0.0114 - loss: 3.2911 - precision: 0.4061 - recall: 0.406 ━━━━━━━━━━━━━━━━━━━━ 58s 301ms/step - accuracy: 0.4027 - f1_score: 0.0118 - loss: 3.2910 - precision: 0.4027 - recall: 0.402 ━━━━━━━━━━━━━━━━━━━━ 58s 299ms/step - accuracy: 0.4006 - f1_score: 0.0124 - loss: 3.2872 - precision: 0.4006 - recall: 0.400 ━━━━━━━━━━━━━━━━━━━━ 57s 298ms/step - accuracy: 0.3982 - f1_score: 0.0129 - loss: 3.2891 - precision: 0.3982 - recall: 0.398 ━━━━━━━━━━━━━━━━━━━━ 56s 297ms/step - accuracy: 0.3957 - f1_score: 0.0134 - loss: 3.2915 - precision: 0.3957 - recall: 0.395 ━━━━━━━━━━━━━━━━━━━━ 56s 296ms/step - accuracy: 0.3932 - f1_score: 0.0140 - loss: 3.2921 - precision: 0.3932 - recall: 0.393 ━━━━━━━━━━━━━━━━━━━━ 56s 295ms/step - accuracy: 0.3906 - f1_score: 0.0145 - loss: 3.2948 - precision: 0.3906 - recall: 0.390 ━━━━━━━━━━━━━━━━━━━━ 55s 294ms/step - accuracy: 0.3877 - f1_score: 0.0150 - loss: 3.2973 - precision: 0.3877 - recall: 0.387 ━━━━━━━━━━━━━━━━━━━━ 55s 294ms/step - accuracy: 0.3847 - f1_score: 0.0154 - loss: 3.3004 - precision: 0.3847 - recall: 0.384 ━━━━━━━━━━━━━━━━━━━━ 54s 293ms/step - accuracy: 0.3816 - f1_score: 0.0158 - loss: 3.3041 - precision: 0.3816 - recall: 0.381 ━━━━━━━━━━━━━━━━━━━━ 54s 293ms/step - accuracy: 0.3785 - f1_score: 0.0163 - loss: 3.3077 - precision: 0.3785 - recall: 0.378 ━━━━━━━━━━━━━━━━━━━━ 54s 292ms/step - accuracy: 0.3755 - f1_score: 0.0167 - loss: 3.3109 - precision: 0.3755 - recall: 0.375 ━━━━━━━━━━━━━━━━━━━━ 53s 292ms/step - accuracy: 0.3724 - f1_score: 0.0171 - loss: 3.3143 - precision: 0.3724 - recall: 0.372 ━━━━━━━━━━━━━━━━━━━━ 53s 292ms/step - accuracy: 0.3696 - f1_score: 0.0176 - loss: 3. ...
# Epoch 4/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 1:36 453ms/step - accuracy: 0.0000e+00 - f1_score: 0.0000e+00 - loss: 4.4687 - precision: 0.0000e+00 - recall: 0.0000e+ ━━━━━━━━━━━━━━━━━━━━ 1:05 309ms/step - accuracy: 0.2500 - f1_score: 0.0017 - loss: 3.4065 - precision: 0.2500 - recall: 0.2500               ━━━━━━━━━━━━━━━━━━━━ 1:02 296ms/step - accuracy: 0.3611 - f1_score: 0.0023 - loss: 2.8932 - precision: 0.3611 - recall: 0.36 ━━━━━━━━━━━━━━━━━━━━ 1:01 290ms/step - accuracy: 0.4115 - f1_score: 0.0041 - loss: 2.6679 - precision: 0.4115 - recall: 0.41 ━━━━━━━━━━━━━━━━━━━━ 1:01 291ms/step - accuracy: 0.4429 - f1_score: 0.0057 - loss: 2.5169 - precision: 0.4429 - recall: 0.44 ━━━━━━━━━━━━━━━━━━━━ 1:00 288ms/step - accuracy: 0.4481 - f1_score: 0.0065 - loss: 2.4758 - precision: 0.4481 - recall: 0.44 ━━━━━━━━━━━━━━━━━━━━ 59s 288ms/step - accuracy: 0.4434 - f1_score: 0.0071 - loss: 2.4734 - precision: 0.4434 - recall: 0.4434 ━━━━━━━━━━━━━━━━━━━━ 1:00 291ms/step - accuracy: 0.4480 - f1_score: 0.0080 - loss: 2.4526 - precision: 0.4480 - recall: 0.44 ━━━━━━━━━━━━━━━━━━━━ 1:00 294ms/step - accuracy: 0.4580 - f1_score: 0.0088 - loss: 2.4083 - precision: 0.4580 - recall: 0.45 ━━━━━━━━━━━━━━━━━━━━ 1:00 296ms/step - accuracy: 0.4619 - f1_score: 0.0094 - loss: 2.4012 - precision: 0.4619 - recall: 0.46 ━━━━━━━━━━━━━━━━━━━━ 1:00 294ms/step - accuracy: 0.4659 - f1_score: 0.0102 - loss: 2.3898 - precision: 0.4659 - recall: 0.46 ━━━━━━━━━━━━━━━━━━━━ 59s 292ms/step - accuracy: 0.4659 - f1_score: 0.0108 - loss: 2.3822 - precision: 0.4659 - recall: 0.4659 ━━━━━━━━━━━━━━━━━━━━ 59s 292ms/step - accuracy: 0.4645 - f1_score: 0.0115 - loss: 2.3905 - precision: 0.4645 - recall: 0.464 ━━━━━━━━━━━━━━━━━━━━ 58s 293ms/step - accuracy: 0.4616 - f1_score: 0.0123 - loss: 2.4028 - precision: 0.4616 - recall: 0.461 ━━━━━━━━━━━━━━━━━━━━ 58s 293ms/step - accuracy: 0.4592 - f1_score: 0.0130 - loss: 2.4137 - precision: 0.4592 - recall: 0.459 ━━━━━━━━━━━━━━━━━━━━ 59s 297ms/step - accuracy: 0.4555 - f1_score: 0.0136 - loss: 2.4287 - precision: 0.4555 - recall: 0.455 ━━━━━━━━━━━━━━━━━━━━ 59s 302ms/step - accuracy: 0.4515 - f1_score: 0.0142 - loss: 2.4426 - precision: 0.4515 - recall: 0.451 ━━━━━━━━━━━━━━━━━━━━ 59s 301ms/step - accuracy: 0.4481 - f1_score: 0.0151 - loss: 2.4547 - precision: 0.4481 - recall: 0.448 ━━━━━━━━━━━━━━━━━━━━ 58s 300ms/step - accuracy: 0.4455 - f1_score: 0.0158 - loss: 2.4628 - precision: 0.4455 - recall: 0.445 ━━━━━━━━━━━━━━━━━━━━ 58s 300ms/step - accuracy: 0.4433 - f1_score: 0.0165 - loss: 2.4734 - precision: 0.4433 - recall: 0.443 ━━━━━━━━━━━━━━━━━━━━ 58s 300ms/step - accuracy: 0.4423 - f1_score: 0.0173 - loss: 2.4796 - precision: 0.4423 - recall: 0.442 ━━━━━━━━━━━━━━━━━━━━ 57s 299ms/step - accuracy: 0.4407 - f1_score: 0.0179 - loss: 2.4896 - precision: 0.4407 - recall: 0.440 ━━━━━━━━━━━━━━━━━━━━ 57s 298ms/step - accuracy: 0.4391 - f1_score: 0.0188 - loss: 2.4994 - precision: 0.4391 - recall: 0.439 ━━━━━━━━━━━━━━━━━━━━ 56s 297ms/step - accuracy: 0.4377 - f1_score: 0.0195 - loss: 2.5072 - precision: 0.4377 - recall: 0.437 ━━━━━━━━━━━━━━━━━━━━ 56s 296ms/step - accuracy: 0.4359 - f1_score: 0.0202 - loss: 2.5161 - precision: 0.4359 - recall: 0.435 ━━━━━━━━━━━━━━━━━━━━ 55s 295ms/step - accuracy: 0.4341 - f1_score: 0.0210 - loss: 2.5237 - precision: 0.4341 - recall: 0.434 ━━━━━━━━━━━━━━━━━━━━ 55s 296ms/step - accuracy: 0.4320 - f1_score: 0.0216 - loss: 2.5312 - precision: 0.4320 - recall: 0.432 ━━━━━━━━━━━━━━━━━━━━ 55s 295ms/step - accuracy: 0.4295 - f1_score: 0.0223 - loss: 2.5393 - precision: 0.4295 - recall: 0.429 ━━━━━━━━━━━━━━━━━━━━ 54s 295ms/step - accuracy: 0.4271 - f1_score: 0.0229 - loss: 2.5473 - precision: 0.4271 - recall: 0.427 ━━━━━━━━━━━━━━━━━━━━ 54s 294ms/step - accuracy: 0.4247 - f1_score: 0.0236 - loss: 2.5545 - precision: 0.4247 - recall: 0.424 ━━━━━━━━━━━━━━━━━━━━ 54s 294ms/step - accuracy: 0.4223 - f1_score: 0.0243 - loss: 2.5616 - precision: 0.4223 - recall: 0.422 ━━━━━━━━━━━━━━━━━━━━ 53s 295ms/step - accuracy: 0.4203 - f1_score: 0.0251 - loss: 2 ...
# Epoch 5/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 1:32 435ms/step - accuracy: 0.4062 - f1_score: 0.0029 - loss: 2.3276 - precision: 0.4062 - recall: 0.40 ━━━━━━━━━━━━━━━━━━━━ 59s 278ms/step - accuracy: 0.5547 - f1_score: 0.0035 - loss: 1.7471 - precision: 0.5547 - recall: 0.5547 ━━━━━━━━━━━━━━━━━━━━ 1:01 289ms/step - accuracy: 0.6094 - f1_score: 0.0037 - loss: 1.5575 - precision: 0.6094 - recall: 0.60 ━━━━━━━━━━━━━━━━━━━━ 1:00 285ms/step - accuracy: 0.6309 - f1_score: 0.0063 - loss: 1.4976 - precision: 0.6309 - recall: 0.63 ━━━━━━━━━━━━━━━━━━━━ 59s 281ms/step - accuracy: 0.6534 - f1_score: 0.0090 - loss: 1.4446 - precision: 0.6534 - recall: 0.6534 ━━━━━━━━━━━━━━━━━━━━ 59s 283ms/step - accuracy: 0.6478 - f1_score: 0.0098 - loss: 1.5009 - precision: 0.6478 - recall: 0.647 ━━━━━━━━━━━━━━━━━━━━ 59s 285ms/step - accuracy: 0.6325 - f1_score: 0.0103 - loss: 1.5504 - precision: 0.6325 - recall: 0.632 ━━━━━━━━━━━━━━━━━━━━ 59s 287ms/step - accuracy: 0.6271 - f1_score: 0.0113 - loss: 1.5658 - precision: 0.6271 - recall: 0.627 ━━━━━━━━━━━━━━━━━━━━ 58s 286ms/step - accuracy: 0.6280 - f1_score: 0.0120 - loss: 1.5575 - precision: 0.6280 - recall: 0.628 ━━━━━━━━━━━━━━━━━━━━ 59s 289ms/step - accuracy: 0.6237 - f1_score: 0.0126 - loss: 1.5806 - precision: 0.6237 - recall: 0.623 ━━━━━━━━━━━━━━━━━━━━ 59s 292ms/step - accuracy: 0.6207 - f1_score: 0.0134 - loss: 1.5963 - precision: 0.6207 - recall: 0.620 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.6159 - f1_score: 0.0141 - loss: 1.6099 - precision: 0.6159 - recall: 0.615 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.6099 - f1_score: 0.0149 - loss: 1.6407 - precision: 0.6099 - recall: 0.609 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.6033 - f1_score: 0.0159 - loss: 1.6733 - precision: 0.6033 - recall: 0.603 ━━━━━━━━━━━━━━━━━━━━ 58s 291ms/step - accuracy: 0.5975 - f1_score: 0.0169 - loss: 1.7011 - precision: 0.5975 - recall: 0.597 ━━━━━━━━━━━━━━━━━━━━ 58s 295ms/step - accuracy: 0.5910 - f1_score: 0.0178 - loss: 1.7288 - precision: 0.5910 - recall: 0.591 ━━━━━━━━━━━━━━━━━━━━ 58s 297ms/step - accuracy: 0.5842 - f1_score: 0.0186 - loss: 1.7558 - precision: 0.5842 - recall: 0.584 ━━━━━━━━━━━━━━━━━━━━ 58s 297ms/step - accuracy: 0.5785 - f1_score: 0.0199 - loss: 1.7790 - precision: 0.5785 - recall: 0.578 ━━━━━━━━━━━━━━━━━━━━ 58s 297ms/step - accuracy: 0.5736 - f1_score: 0.0209 - loss: 1.7977 - precision: 0.5736 - recall: 0.573 ━━━━━━━━━━━━━━━━━━━━ 57s 296ms/step - accuracy: 0.5693 - f1_score: 0.0218 - loss: 1.8174 - precision: 0.5693 - recall: 0.569 ━━━━━━━━━━━━━━━━━━━━ 57s 296ms/step - accuracy: 0.5662 - f1_score: 0.0228 - loss: 1.8321 - precision: 0.5662 - recall: 0.566 ━━━━━━━━━━━━━━━━━━━━ 56s 295ms/step - accuracy: 0.5627 - f1_score: 0.0237 - loss: 1.8487 - precision: 0.5627 - recall: 0.562 ━━━━━━━━━━━━━━━━━━━━ 56s 295ms/step - accuracy: 0.5592 - f1_score: 0.0248 - loss: 1.8641 - precision: 0.5592 - recall: 0.559 ━━━━━━━━━━━━━━━━━━━━ 56s 293ms/step - accuracy: 0.5565 - f1_score: 0.0258 - loss: 1.8770 - precision: 0.5565 - recall: 0.556 ━━━━━━━━━━━━━━━━━━━━ 55s 295ms/step - accuracy: 0.5537 - f1_score: 0.0270 - loss: 1.8908 - precision: 0.5537 - recall: 0.553 ━━━━━━━━━━━━━━━━━━━━ 55s 295ms/step - accuracy: 0.5511 - f1_score: 0.0283 - loss: 1.9027 - precision: 0.5511 - recall: 0.551 ━━━━━━━━━━━━━━━━━━━━ 55s 294ms/step - accuracy: 0.5486 - f1_score: 0.0295 - loss: 1.9136 - precision: 0.5486 - recall: 0.548 ━━━━━━━━━━━━━━━━━━━━ 55s 295ms/step - accuracy: 0.5456 - f1_score: 0.0305 - loss: 1.9250 - precision: 0.5456 - recall: 0.545 ━━━━━━━━━━━━━━━━━━━━ 54s 294ms/step - accuracy: 0.5428 - f1_score: 0.0316 - loss: 1.9360 - precision: 0.5428 - recall: 0.542 ━━━━━━━━━━━━━━━━━━━━ 54s 294ms/step - accuracy: 0.5403 - f1_score: 0.0329 - loss: 1.9458 - precision: 0.5403 - recall: 0.540 ━━━━━━━━━━━━━━━━━━━━ 53s 293ms/step - accuracy: 0.5378 - f1_score: 0.0341 - loss: 1.9553 - precision: 0.5378 - recall: 0.537 ━━━━━━━━━━━━━━━━━━━━ 53s 293ms/step - accuracy: 0.5358 - f1_score: 0.0354 - loss: 1.9625 - precision: 0.5358 - reca ...
# Epoch 6/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 42:31 12s/step - accuracy: 0.5312 - f1_score: 0.0034 - loss: 1.5419 - precision: 0.5312 - recall: 0.531 ━━━━━━━━━━━━━━━━━━━━ 1:00 284ms/step - accuracy: 0.6484 - f1_score: 0.0039 - loss: 1.1579 - precision: 0.6484 - recall: 0.64 ━━━━━━━━━━━━━━━━━━━━ 1:00 283ms/step - accuracy: 0.6858 - f1_score: 0.0040 - loss: 1.0779 - precision: 0.6858 - recall: 0.68 ━━━━━━━━━━━━━━━━━━━━ 59s 280ms/step - accuracy: 0.6999 - f1_score: 0.0067 - loss: 1.0431 - precision: 0.6999 - recall: 0.6999 ━━━━━━━━━━━━━━━━━━━━ 58s 279ms/step - accuracy: 0.7174 - f1_score: 0.0095 - loss: 1.0169 - precision: 0.7174 - recall: 0.717 ━━━━━━━━━━━━━━━━━━━━ 57s 275ms/step - accuracy: 0.7098 - f1_score: 0.0104 - loss: 1.0851 - precision: 0.7098 - recall: 0.709 ━━━━━━━━━━━━━━━━━━━━ 57s 276ms/step - accuracy: 0.6977 - f1_score: 0.0117 - loss: 1.1366 - precision: 0.6977 - recall: 0.697 ━━━━━━━━━━━━━━━━━━━━ 57s 277ms/step - accuracy: 0.6935 - f1_score: 0.0129 - loss: 1.1568 - precision: 0.6935 - recall: 0.693 ━━━━━━━━━━━━━━━━━━━━ 57s 277ms/step - accuracy: 0.6944 - f1_score: 0.0139 - loss: 1.1570 - precision: 0.6944 - recall: 0.694 ━━━━━━━━━━━━━━━━━━━━ 57s 281ms/step - accuracy: 0.6893 - f1_score: 0.0147 - loss: 1.1822 - precision: 0.6893 - recall: 0.689 ━━━━━━━━━━━━━━━━━━━━ 57s 281ms/step - accuracy: 0.6863 - f1_score: 0.0158 - loss: 1.1990 - precision: 0.6863 - recall: 0.686 ━━━━━━━━━━━━━━━━━━━━ 56s 280ms/step - accuracy: 0.6831 - f1_score: 0.0170 - loss: 1.2137 - precision: 0.6831 - recall: 0.683 ━━━━━━━━━━━━━━━━━━━━ 56s 280ms/step - accuracy: 0.6781 - f1_score: 0.0180 - loss: 1.2497 - precision: 0.6781 - recall: 0.678 ━━━━━━━━━━━━━━━━━━━━ 56s 283ms/step - accuracy: 0.6724 - f1_score: 0.0193 - loss: 1.2861 - precision: 0.6724 - recall: 0.672 ━━━━━━━━━━━━━━━━━━━━ 56s 284ms/step - accuracy: 0.6676 - f1_score: 0.0206 - loss: 1.3161 - precision: 0.6676 - recall: 0.667 ━━━━━━━━━━━━━━━━━━━━ 57s 288ms/step - accuracy: 0.6625 - f1_score: 0.0219 - loss: 1.3441 - precision: 0.6625 - recall: 0.662 ━━━━━━━━━━━━━━━━━━━━ 57s 289ms/step - accuracy: 0.6570 - f1_score: 0.0232 - loss: 1.3698 - precision: 0.6570 - recall: 0.657 ━━━━━━━━━━━━━━━━━━━━ 56s 289ms/step - accuracy: 0.6522 - f1_score: 0.0248 - loss: 1.3916 - precision: 0.6522 - recall: 0.652 ━━━━━━━━━━━━━━━━━━━━ 56s 287ms/step - accuracy: 0.6481 - f1_score: 0.0262 - loss: 1.4106 - precision: 0.6481 - recall: 0.648 ━━━━━━━━━━━━━━━━━━━━ 55s 286ms/step - accuracy: 0.6442 - f1_score: 0.0274 - loss: 1.4298 - precision: 0.6442 - recall: 0.644 ━━━━━━━━━━━━━━━━━━━━ 55s 287ms/step - accuracy: 0.6415 - f1_score: 0.0287 - loss: 1.4442 - precision: 0.6415 - recall: 0.641 ━━━━━━━━━━━━━━━━━━━━ 55s 286ms/step - accuracy: 0.6382 - f1_score: 0.0299 - loss: 1.4586 - precision: 0.6382 - recall: 0.638 ━━━━━━━━━━━━━━━━━━━━ 54s 286ms/step - accuracy: 0.6353 - f1_score: 0.0313 - loss: 1.4715 - precision: 0.6353 - recall: 0.635 ━━━━━━━━━━━━━━━━━━━━ 54s 285ms/step - accuracy: 0.6329 - f1_score: 0.0327 - loss: 1.4822 - precision: 0.6329 - recall: 0.632 ━━━━━━━━━━━━━━━━━━━━ 54s 286ms/step - accuracy: 0.6305 - f1_score: 0.0343 - loss: 1.4931 - precision: 0.6305 - recall: 0.630 ━━━━━━━━━━━━━━━━━━━━ 54s 287ms/step - accuracy: 0.6281 - f1_score: 0.0360 - loss: 1.5027 - precision: 0.6281 - recall: 0.628 ━━━━━━━━━━━━━━━━━━━━ 53s 286ms/step - accuracy: 0.6257 - f1_score: 0.0375 - loss: 1.5116 - precision: 0.6257 - recall: 0.625 ━━━━━━━━━━━━━━━━━━━━ 53s 286ms/step - accuracy: 0.6230 - f1_score: 0.0389 - loss: 1.5207 - precision: 0.6230 - recall: 0.623 ━━━━━━━━━━━━━━━━━━━━ 53s 285ms/step - accuracy: 0.6206 - f1_score: 0.0405 - loss: 1.5294 - precision: 0.6206 - recall: 0.620 ━━━━━━━━━━━━━━━━━━━━ 52s 285ms/step - accuracy: 0.6187 - f1_score: 0.0423 - loss: 1.5369 - precision: 0.6187 - recall: 0.618 ━━━━━━━━━━━━━━━━━━━━ 52s 285ms/step - accuracy: 0.6167 - f1_score: 0.0440 - loss: 1.5443 - precision: 0.6167 - recall: 0.616 ━━━━━━━━━━━━━━━━━━━━ 52s 284ms/step - accuracy: 0.6153 - f1_score: 0.0457 - loss: 1.5497 - precision: 0.6153 - recal ...
# Epoch 7/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 1:34 443ms/step - accuracy: 0.8125 - f1_score: 0.0044 - loss: 0.9210 - precision: 0.8125 - recall: 0.81 ━━━━━━━━━━━━━━━━━━━━ 58s 274ms/step - accuracy: 0.8594 - f1_score: 0.0046 - loss: 0.6914 - precision: 0.8594 - recall: 0.8594 ━━━━━━━━━━━━━━━━━━━━ 57s 273ms/step - accuracy: 0.8611 - f1_score: 0.0050 - loss: 0.6558 - precision: 0.8611 - recall: 0.861 ━━━━━━━━━━━━━━━━━━━━ 57s 274ms/step - accuracy: 0.8665 - f1_score: 0.0082 - loss: 0.6233 - precision: 0.8665 - recall: 0.866 ━━━━━━━━━━━━━━━━━━━━ 59s 284ms/step - accuracy: 0.8732 - f1_score: 0.0111 - loss: 0.6084 - precision: 0.8732 - recall: 0.873 ━━━━━━━━━━━━━━━━━━━━ 59s 283ms/step - accuracy: 0.8588 - f1_score: 0.0123 - loss: 0.6607 - precision: 0.8588 - recall: 0.858 ━━━━━━━━━━━━━━━━━━━━ 59s 286ms/step - accuracy: 0.8369 - f1_score: 0.0133 - loss: 0.7119 - precision: 0.8369 - recall: 0.836 ━━━━━━━━━━━━━━━━━━━━ 59s 286ms/step - accuracy: 0.8250 - f1_score: 0.0147 - loss: 0.7384 - precision: 0.8250 - recall: 0.825 ━━━━━━━━━━━━━━━━━━━━ 58s 285ms/step - accuracy: 0.8190 - f1_score: 0.0157 - loss: 0.7480 - precision: 0.8190 - recall: 0.819 ━━━━━━━━━━━━━━━━━━━━ 59s 289ms/step - accuracy: 0.8108 - f1_score: 0.0171 - loss: 0.7683 - precision: 0.8108 - recall: 0.810 ━━━━━━━━━━━━━━━━━━━━ 58s 288ms/step - accuracy: 0.8045 - f1_score: 0.0184 - loss: 0.7826 - precision: 0.8045 - recall: 0.804 ━━━━━━━━━━━━━━━━━━━━ 58s 287ms/step - accuracy: 0.7983 - f1_score: 0.0198 - loss: 0.7985 - precision: 0.7983 - recall: 0.798 ━━━━━━━━━━━━━━━━━━━━ 58s 288ms/step - accuracy: 0.7901 - f1_score: 0.0210 - loss: 0.8362 - precision: 0.7901 - recall: 0.790 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.7818 - f1_score: 0.0225 - loss: 0.8738 - precision: 0.7818 - recall: 0.781 ━━━━━━━━━━━━━━━━━━━━ 58s 294ms/step - accuracy: 0.7753 - f1_score: 0.0241 - loss: 0.9047 - precision: 0.7753 - recall: 0.775 ━━━━━━━━━━━━━━━━━━━━ 59s 299ms/step - accuracy: 0.7693 - f1_score: 0.0259 - loss: 0.9325 - precision: 0.7693 - recall: 0.769 ━━━━━━━━━━━━━━━━━━━━ 59s 299ms/step - accuracy: 0.7633 - f1_score: 0.0277 - loss: 0.9574 - precision: 0.7633 - recall: 0.763 ━━━━━━━━━━━━━━━━━━━━ 58s 298ms/step - accuracy: 0.7576 - f1_score: 0.0297 - loss: 0.9790 - precision: 0.7576 - recall: 0.757 ━━━━━━━━━━━━━━━━━━━━ 58s 297ms/step - accuracy: 0.7523 - f1_score: 0.0314 - loss: 0.9988 - precision: 0.7523 - recall: 0.752 ━━━━━━━━━━━━━━━━━━━━ 57s 297ms/step - accuracy: 0.7474 - f1_score: 0.0330 - loss: 1.0178 - precision: 0.7474 - recall: 0.747 ━━━━━━━━━━━━━━━━━━━━ 57s 296ms/step - accuracy: 0.7436 - f1_score: 0.0345 - loss: 1.0325 - precision: 0.7436 - recall: 0.743 ━━━━━━━━━━━━━━━━━━━━ 57s 295ms/step - accuracy: 0.7400 - f1_score: 0.0362 - loss: 1.0454 - precision: 0.7400 - recall: 0.740 ━━━━━━━━━━━━━━━━━━━━ 56s 295ms/step - accuracy: 0.7369 - f1_score: 0.0381 - loss: 1.0572 - precision: 0.7369 - recall: 0.736 ━━━━━━━━━━━━━━━━━━━━ 56s 294ms/step - accuracy: 0.7342 - f1_score: 0.0399 - loss: 1.0669 - precision: 0.7342 - recall: 0.734 ━━━━━━━━━━━━━━━━━━━━ 55s 293ms/step - accuracy: 0.7314 - f1_score: 0.0419 - loss: 1.0778 - precision: 0.7314 - recall: 0.731 ━━━━━━━━━━━━━━━━━━━━ 55s 295ms/step - accuracy: 0.7290 - f1_score: 0.0440 - loss: 1.0868 - precision: 0.7290 - recall: 0.729 ━━━━━━━━━━━━━━━━━━━━ 55s 295ms/step - accuracy: 0.7265 - f1_score: 0.0460 - loss: 1.0952 - precision: 0.7265 - recall: 0.726 ━━━━━━━━━━━━━━━━━━━━ 55s 295ms/step - accuracy: 0.7238 - f1_score: 0.0479 - loss: 1.1033 - precision: 0.7238 - recall: 0.723 ━━━━━━━━━━━━━━━━━━━━ 54s 295ms/step - accuracy: 0.7215 - f1_score: 0.0500 - loss: 1.1108 - precision: 0.7215 - recall: 0.721 ━━━━━━━━━━━━━━━━━━━━ 54s 295ms/step - accuracy: 0.7195 - f1_score: 0.0523 - loss: 1.1170 - precision: 0.7195 - recall: 0.719 ━━━━━━━━━━━━━━━━━━━━ 54s 295ms/step - accuracy: 0.7175 - f1_score: 0.0544 - loss: 1.1234 - precision: 0.7175 - recall: 0.717 ━━━━━━━━━━━━━━━━━━━━ 53s 295ms/step - accuracy: 0.7159 - f1_score: 0.0564 - loss: 1.1281 - precision: 0.7159 - recal ...
# Epoch 8/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 1:36 453ms/step - accuracy: 0.9062 - f1_score: 0.0047 - loss: 0.4307 - precision: 0.9062 - recall: 0.90 ━━━━━━━━━━━━━━━━━━━━ 1:03 300ms/step - accuracy: 0.9297 - f1_score: 0.0048 - loss: 0.3231 - precision: 0.9297 - recall: 0.92 ━━━━━━━━━━━━━━━━━━━━ 1:01 292ms/step - accuracy: 0.9219 - f1_score: 0.0054 - loss: 0.3364 - precision: 0.9219 - recall: 0.92 ━━━━━━━━━━━━━━━━━━━━ 1:00 285ms/step - accuracy: 0.9238 - f1_score: 0.0087 - loss: 0.3291 - precision: 0.9238 - recall: 0.92 ━━━━━━━━━━━━━━━━━━━━ 1:00 289ms/step - accuracy: 0.9191 - f1_score: 0.0115 - loss: 0.3476 - precision: 0.9191 - recall: 0.91 ━━━━━━━━━━━━━━━━━━━━ 1:01 295ms/step - accuracy: 0.9039 - f1_score: 0.0130 - loss: 0.3903 - precision: 0.9039 - recall: 0.90 ━━━━━━━━━━━━━━━━━━━━ 1:02 298ms/step - accuracy: 0.8864 - f1_score: 0.0148 - loss: 0.4356 - precision: 0.8864 - recall: 0.88 ━━━━━━━━━━━━━━━━━━━━ 1:01 298ms/step - accuracy: 0.8767 - f1_score: 0.0164 - loss: 0.4602 - precision: 0.8767 - recall: 0.87 ━━━━━━━━━━━━━━━━━━━━ 1:01 297ms/step - accuracy: 0.8715 - f1_score: 0.0177 - loss: 0.4721 - precision: 0.8715 - recall: 0.87 ━━━━━━━━━━━━━━━━━━━━ 1:00 297ms/step - accuracy: 0.8646 - f1_score: 0.0194 - loss: 0.4890 - precision: 0.8646 - recall: 0.86 ━━━━━━━━━━━━━━━━━━━━ 1:00 294ms/step - accuracy: 0.8599 - f1_score: 0.0211 - loss: 0.5012 - precision: 0.8599 - recall: 0.85 ━━━━━━━━━━━━━━━━━━━━ 59s 293ms/step - accuracy: 0.8553 - f1_score: 0.0227 - loss: 0.5176 - precision: 0.8553 - recall: 0.8553 ━━━━━━━━━━━━━━━━━━━━ 59s 293ms/step - accuracy: 0.8481 - f1_score: 0.0241 - loss: 0.5481 - precision: 0.8481 - recall: 0.848 ━━━━━━━━━━━━━━━━━━━━ 1:00 299ms/step - accuracy: 0.8409 - f1_score: 0.0259 - loss: 0.5778 - precision: 0.8409 - recall: 0.84 ━━━━━━━━━━━━━━━━━━━━ 1:00 303ms/step - accuracy: 0.8353 - f1_score: 0.0278 - loss: 0.6018 - precision: 0.8353 - recall: 0.83 ━━━━━━━━━━━━━━━━━━━━ 1:00 303ms/step - accuracy: 0.8301 - f1_score: 0.0298 - loss: 0.6240 - precision: 0.8301 - recall: 0.83 ━━━━━━━━━━━━━━━━━━━━ 59s 302ms/step - accuracy: 0.8255 - f1_score: 0.0321 - loss: 0.6441 - precision: 0.8255 - recall: 0.8255 ━━━━━━━━━━━━━━━━━━━━ 59s 301ms/step - accuracy: 0.8219 - f1_score: 0.0346 - loss: 0.6608 - precision: 0.8219 - recall: 0.821 ━━━━━━━━━━━━━━━━━━━━ 58s 301ms/step - accuracy: 0.8182 - f1_score: 0.0368 - loss: 0.6773 - precision: 0.8182 - recall: 0.818 ━━━━━━━━━━━━━━━━━━━━ 58s 301ms/step - accuracy: 0.8150 - f1_score: 0.0389 - loss: 0.6917 - precision: 0.8150 - recall: 0.815 ━━━━━━━━━━━━━━━━━━━━ 58s 300ms/step - accuracy: 0.8125 - f1_score: 0.0409 - loss: 0.7032 - precision: 0.8125 - recall: 0.812 ━━━━━━━━━━━━━━━━━━━━ 57s 300ms/step - accuracy: 0.8102 - f1_score: 0.0430 - loss: 0.7130 - precision: 0.8102 - recall: 0.810 ━━━━━━━━━━━━━━━━━━━━ 57s 301ms/step - accuracy: 0.8084 - f1_score: 0.0453 - loss: 0.7217 - precision: 0.8084 - recall: 0.808 ━━━━━━━━━━━━━━━━━━━━ 57s 301ms/step - accuracy: 0.8069 - f1_score: 0.0477 - loss: 0.7288 - precision: 0.8069 - recall: 0.806 ━━━━━━━━━━━━━━━━━━━━ 57s 301ms/step - accuracy: 0.8050 - f1_score: 0.0500 - loss: 0.7377 - precision: 0.8050 - recall: 0.805 ━━━━━━━━━━━━━━━━━━━━ 56s 301ms/step - accuracy: 0.8037 - f1_score: 0.0525 - loss: 0.7447 - precision: 0.8037 - recall: 0.803 ━━━━━━━━━━━━━━━━━━━━ 56s 300ms/step - accuracy: 0.8022 - f1_score: 0.0549 - loss: 0.7512 - precision: 0.8022 - recall: 0.802 ━━━━━━━━━━━━━━━━━━━━ 55s 299ms/step - accuracy: 0.8008 - f1_score: 0.0574 - loss: 0.7570 - precision: 0.8008 - recall: 0.800 ━━━━━━━━━━━━━━━━━━━━ 55s 298ms/step - accuracy: 0.7995 - f1_score: 0.0600 - loss: 0.7623 - precision: 0.7995 - recall: 0.799 ━━━━━━━━━━━━━━━━━━━━ 55s 298ms/step - accuracy: 0.7986 - f1_score: 0.0628 - loss: 0.7666 - precision: 0.7986 - recall: 0.798 ━━━━━━━━━━━━━━━━━━━━ 54s 298ms/step - accuracy: 0.7976 - f1_score: 0.0655 - loss: 0.7710 - precision: 0.7976 - recall: 0.797 ━━━━━━━━━━━━━━━━━━━━ 54s 300ms/step - accuracy: 0.7969 - f1_score: 0.0680 - loss: 0.7743 - precision: 0.7969 - reca ...
# Epoch 9/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 1:29 420ms/step - accuracy: 0.9375 - f1_score: 0.0048 - loss: 0.1955 - precision: 0.9375 - recall: 0.93 ━━━━━━━━━━━━━━━━━━━━ 1:07 316ms/step - accuracy: 0.9531 - f1_score: 0.0048 - loss: 0.1468 - precision: 0.9531 - recall: 0.95 ━━━━━━━━━━━━━━━━━━━━ 1:03 301ms/step - accuracy: 0.9618 - f1_score: 0.0065 - loss: 0.1251 - precision: 0.9618 - recall: 0.96 ━━━━━━━━━━━━━━━━━━━━ 1:02 298ms/step - accuracy: 0.9674 - f1_score: 0.0098 - loss: 0.1117 - precision: 0.9674 - recall: 0.96 ━━━━━━━━━━━━━━━━━━━━ 1:01 292ms/step - accuracy: 0.9590 - f1_score: 0.0126 - loss: 0.1470 - precision: 0.9590 - recall: 0.95 ━━━━━━━━━━━━━━━━━━━━ 1:01 292ms/step - accuracy: 0.9441 - f1_score: 0.0141 - loss: 0.1930 - precision: 0.9441 - recall: 0.94 ━━━━━━━━━━━━━━━━━━━━ 1:00 292ms/step - accuracy: 0.9298 - f1_score: 0.0162 - loss: 0.2311 - precision: 0.9298 - recall: 0.92 ━━━━━━━━━━━━━━━━━━━━ 1:00 294ms/step - accuracy: 0.9215 - f1_score: 0.0179 - loss: 0.2536 - precision: 0.9215 - recall: 0.92 ━━━━━━━━━━━━━━━━━━━━ 1:00 295ms/step - accuracy: 0.9167 - f1_score: 0.0194 - loss: 0.2663 - precision: 0.9167 - recall: 0.91 ━━━━━━━━━━━━━━━━━━━━ 1:00 296ms/step - accuracy: 0.9113 - f1_score: 0.0213 - loss: 0.2806 - precision: 0.9113 - recall: 0.91 ━━━━━━━━━━━━━━━━━━━━ 1:01 300ms/step - accuracy: 0.9077 - f1_score: 0.0233 - loss: 0.2906 - precision: 0.9077 - recall: 0.90 ━━━━━━━━━━━━━━━━━━━━ 1:00 299ms/step - accuracy: 0.9043 - f1_score: 0.0252 - loss: 0.3066 - precision: 0.9043 - recall: 0.90 ━━━━━━━━━━━━━━━━━━━━ 59s 297ms/step - accuracy: 0.8987 - f1_score: 0.0269 - loss: 0.3320 - precision: 0.8987 - recall: 0.8987 ━━━━━━━━━━━━━━━━━━━━ 59s 297ms/step - accuracy: 0.8934 - f1_score: 0.0291 - loss: 0.3559 - precision: 0.8934 - recall: 0.893 ━━━━━━━━━━━━━━━━━━━━ 59s 297ms/step - accuracy: 0.8892 - f1_score: 0.0312 - loss: 0.3747 - precision: 0.8892 - recall: 0.889 ━━━━━━━━━━━━━━━━━━━━ 59s 301ms/step - accuracy: 0.8858 - f1_score: 0.0337 - loss: 0.3902 - precision: 0.8858 - recall: 0.885 ━━━━━━━━━━━━━━━━━━━━ 59s 302ms/step - accuracy: 0.8818 - f1_score: 0.0361 - loss: 0.4067 - precision: 0.8818 - recall: 0.881 ━━━━━━━━━━━━━━━━━━━━ 59s 301ms/step - accuracy: 0.8788 - f1_score: 0.0389 - loss: 0.4198 - precision: 0.8788 - recall: 0.878 ━━━━━━━━━━━━━━━━━━━━ 58s 300ms/step - accuracy: 0.8757 - f1_score: 0.0413 - loss: 0.4338 - precision: 0.8757 - recall: 0.875 ━━━━━━━━━━━━━━━━━━━━ 58s 302ms/step - accuracy: 0.8732 - f1_score: 0.0437 - loss: 0.4453 - precision: 0.8732 - recall: 0.873 ━━━━━━━━━━━━━━━━━━━━ 58s 302ms/step - accuracy: 0.8710 - f1_score: 0.0458 - loss: 0.4549 - precision: 0.8710 - recall: 0.871 ━━━━━━━━━━━━━━━━━━━━ 57s 300ms/step - accuracy: 0.8687 - f1_score: 0.0481 - loss: 0.4638 - precision: 0.8687 - recall: 0.868 ━━━━━━━━━━━━━━━━━━━━ 57s 299ms/step - accuracy: 0.8667 - f1_score: 0.0506 - loss: 0.4717 - precision: 0.8667 - recall: 0.866 ━━━━━━━━━━━━━━━━━━━━ 57s 299ms/step - accuracy: 0.8651 - f1_score: 0.0530 - loss: 0.4783 - precision: 0.8651 - recall: 0.865 ━━━━━━━━━━━━━━━━━━━━ 56s 297ms/step - accuracy: 0.8628 - f1_score: 0.0555 - loss: 0.4887 - precision: 0.8628 - recall: 0.862 ━━━━━━━━━━━━━━━━━━━━ 56s 297ms/step - accuracy: 0.8610 - f1_score: 0.0581 - loss: 0.4973 - precision: 0.8610 - recall: 0.861 ━━━━━━━━━━━━━━━━━━━━ 56s 299ms/step - accuracy: 0.8593 - f1_score: 0.0607 - loss: 0.5052 - precision: 0.8593 - recall: 0.859 ━━━━━━━━━━━━━━━━━━━━ 55s 299ms/step - accuracy: 0.8580 - f1_score: 0.0634 - loss: 0.5121 - precision: 0.8580 - recall: 0.858 ━━━━━━━━━━━━━━━━━━━━ 55s 298ms/step - accuracy: 0.8569 - f1_score: 0.0663 - loss: 0.5181 - precision: 0.8569 - recall: 0.856 ━━━━━━━━━━━━━━━━━━━━ 55s 298ms/step - accuracy: 0.8560 - f1_score: 0.0693 - loss: 0.5232 - precision: 0.8560 - recall: 0.856 ━━━━━━━━━━━━━━━━━━━━ 54s 298ms/step - accuracy: 0.8553 - f1_score: 0.0722 - loss: 0.5280 - precision: 0.8553 - recall: 0.855 ━━━━━━━━━━━━━━━━━━━━ 54s 298ms/step - accuracy: 0.8547 - f1_score: 0.0750 - loss: 0.5318 - precision: 0.8547 - recal ...
# Epoch 10/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 1:44 488ms/step - accuracy: 1.0000 - f1_score: 0.0050 - loss: 0.0812 - precision: 1.0000 - recall: 1.00 ━━━━━━━━━━━━━━━━━━━━ 59s 279ms/step - accuracy: 1.0000 - f1_score: 0.0050 - loss: 0.0610 - precision: 1.0000 - recall: 1.0000 ━━━━━━━━━━━━━━━━━━━━ 1:01 290ms/step - accuracy: 1.0000 - f1_score: 0.0066 - loss: 0.0505 - precision: 1.0000 - recall: 1.00 ━━━━━━━━━━━━━━━━━━━━ 1:02 297ms/step - accuracy: 1.0000 - f1_score: 0.0099 - loss: 0.0470 - precision: 1.0000 - recall: 1.00 ━━━━━━━━━━━━━━━━━━━━ 1:03 301ms/step - accuracy: 0.9775 - f1_score: 0.0125 - loss: 0.1250 - precision: 0.9775 - recall: 0.97 ━━━━━━━━━━━━━━━━━━━━ 1:01 295ms/step - accuracy: 0.9639 - f1_score: 0.0141 - loss: 0.1753 - precision: 0.9639 - recall: 0.96 ━━━━━━━━━━━━━━━━━━━━ 1:01 297ms/step - accuracy: 0.9506 - f1_score: 0.0164 - loss: 0.2185 - precision: 0.9506 - recall: 0.95 ━━━━━━━━━━━━━━━━━━━━ 1:02 303ms/step - accuracy: 0.9426 - f1_score: 0.0182 - loss: 0.2440 - precision: 0.9426 - recall: 0.94 ━━━━━━━━━━━━━━━━━━━━ 1:02 303ms/step - accuracy: 0.9378 - f1_score: 0.0197 - loss: 0.2595 - precision: 0.9378 - recall: 0.93 ━━━━━━━━━━━━━━━━━━━━ 1:01 301ms/step - accuracy: 0.9337 - f1_score: 0.0218 - loss: 0.2714 - precision: 0.9337 - recall: 0.93 ━━━━━━━━━━━━━━━━━━━━ 1:01 299ms/step - accuracy: 0.9309 - f1_score: 0.0239 - loss: 0.2799 - precision: 0.9309 - recall: 0.93 ━━━━━━━━━━━━━━━━━━━━ 1:00 297ms/step - accuracy: 0.9280 - f1_score: 0.0259 - loss: 0.2948 - precision: 0.9280 - recall: 0.92 ━━━━━━━━━━━━━━━━━━━━ 59s 296ms/step - accuracy: 0.9237 - f1_score: 0.0279 - loss: 0.3139 - precision: 0.9237 - recall: 0.9237 ━━━━━━━━━━━━━━━━━━━━ 59s 297ms/step - accuracy: 0.9203 - f1_score: 0.0302 - loss: 0.3302 - precision: 0.9203 - recall: 0.920 ━━━━━━━━━━━━━━━━━━━━ 1:00 300ms/step - accuracy: 0.9177 - f1_score: 0.0326 - loss: 0.3425 - precision: 0.9177 - recall: 0.91 ━━━━━━━━━━━━━━━━━━━━ 1:00 305ms/step - accuracy: 0.9156 - f1_score: 0.0353 - loss: 0.3521 - precision: 0.9156 - recall: 0.91 ━━━━━━━━━━━━━━━━━━━━ 1:00 303ms/step - accuracy: 0.9134 - f1_score: 0.0381 - loss: 0.3613 - precision: 0.9134 - recall: 0.91 ━━━━━━━━━━━━━━━━━━━━ 59s 302ms/step - accuracy: 0.9118 - f1_score: 0.0411 - loss: 0.3685 - precision: 0.9118 - recall: 0.9118 ━━━━━━━━━━━━━━━━━━━━ 59s 303ms/step - accuracy: 0.9096 - f1_score: 0.0437 - loss: 0.3775 - precision: 0.9096 - recall: 0.909 ━━━━━━━━━━━━━━━━━━━━ 59s 303ms/step - accuracy: 0.9073 - f1_score: 0.0462 - loss: 0.3863 - precision: 0.9073 - recall: 0.907 ━━━━━━━━━━━━━━━━━━━━ 58s 303ms/step - accuracy: 0.9053 - f1_score: 0.0485 - loss: 0.3939 - precision: 0.9053 - recall: 0.905 ━━━━━━━━━━━━━━━━━━━━ 58s 301ms/step - accuracy: 0.9036 - f1_score: 0.0510 - loss: 0.4000 - precision: 0.9036 - recall: 0.903 ━━━━━━━━━━━━━━━━━━━━ 57s 302ms/step - accuracy: 0.9013 - f1_score: 0.0535 - loss: 0.4072 - precision: 0.9013 - recall: 0.901 ━━━━━━━━━━━━━━━━━━━━ 57s 301ms/step - accuracy: 0.8990 - f1_score: 0.0560 - loss: 0.4141 - precision: 0.8990 - recall: 0.899 ━━━━━━━━━━━━━━━━━━━━ 57s 300ms/step - accuracy: 0.8965 - f1_score: 0.0585 - loss: 0.4222 - precision: 0.8965 - recall: 0.896 ━━━━━━━━━━━━━━━━━━━━ 56s 301ms/step - accuracy: 0.8945 - f1_score: 0.0613 - loss: 0.4288 - precision: 0.8945 - recall: 0.894 ━━━━━━━━━━━━━━━━━━━━ 56s 301ms/step - accuracy: 0.8925 - f1_score: 0.0640 - loss: 0.4349 - precision: 0.8925 - recall: 0.892 ━━━━━━━━━━━━━━━━━━━━ 56s 300ms/step - accuracy: 0.8909 - f1_score: 0.0668 - loss: 0.4400 - precision: 0.8909 - recall: 0.890 ━━━━━━━━━━━━━━━━━━━━ 55s 300ms/step - accuracy: 0.8896 - f1_score: 0.0698 - loss: 0.4442 - precision: 0.8896 - recall: 0.889 ━━━━━━━━━━━━━━━━━━━━ 55s 300ms/step - accuracy: 0.8885 - f1_score: 0.0729 - loss: 0.4476 - precision: 0.8885 - recall: 0.888 ━━━━━━━━━━━━━━━━━━━━ 55s 300ms/step - accuracy: 0.8876 - f1_score: 0.0759 - loss: 0.4507 - precision: 0.8876 - recall: 0.887 ━━━━━━━━━━━━━━━━━━━━ 54s 300ms/step - accuracy: 0.8869 - f1_score: 0.0788 - loss: 0.4531 - precision: 0.8869 - rec ...

# %%
# Evaluate
results = best_model.evaluate(test_dataset, return_dict=True, verbose=0)
print("\nTest set results:")
for metric_name, value in results.items():
    print(f"{metric_name}: {value:.4f}")
# Out:
# Test set results:
# accuracy: 0.0325
# f1_score: 0.0341
# loss: 7.7036
# precision: 0.0325
# recall: 0.0325

# %%
# same model with class_weight

# Instantiate and compile the model
best_model = best_functional_model()
optimizer = optimizers.RMSprop(learning_rate=0.0005838087914898498)

best_model.compile(
    optimizer=optimizer,
    loss=CategoricalCrossentropy(),
    metrics=metrics  
)

# Train the model (sem class_weight)
history = best_model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=10,
    class_weight=class_weight_dict
)
# Out:
# Epoch 1/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 3:53 1s/step - accuracy: 0.0321 - f1_score: 0.0325 - loss: 2.0511 - precision: 0.0321 - recall: 0.032 ━━━━━━━━━━━━━━━━━━━━ 1:49 512ms/step - accuracy: 0.0383 - f1_score: 0.0330 - loss: 1.5383 - precision: 0.0383 - recall: 0.03 ━━━━━━━━━━━━━━━━━━━━ 1:45 498ms/step - accuracy: 0.0434 - f1_score: 0.0333 - loss: 1.8697 - precision: 0.0434 - recall: 0.04 ━━━━━━━━━━━━━━━━━━━━ 1:33 441ms/step - accuracy: 0.0468 - f1_score: 0.0338 - loss: 2.4309 - precision: 0.0468 - recall: 0.04 ━━━━━━━━━━━━━━━━━━━━ 1:22 391ms/step - accuracy: 0.0494 - f1_score: 0.0345 - loss: 2.7066 - precision: 0.0494 - recall: 0.04 ━━━━━━━━━━━━━━━━━━━━ 1:17 371ms/step - accuracy: 0.0510 - f1_score: 0.0348 - loss: 3.0991 - precision: 0.0510 - recall: 0.05 ━━━━━━━━━━━━━━━━━━━━ 1:14 356ms/step - accuracy: 0.0522 - f1_score: 0.0351 - loss: 3.4677 - precision: 0.0522 - recall: 0.05 ━━━━━━━━━━━━━━━━━━━━ 1:11 346ms/step - accuracy: 0.0529 - f1_score: 0.0353 - loss: 3.6877 - precision: 0.0529 - recall: 0.05 ━━━━━━━━━━━━━━━━━━━━ 1:09 338ms/step - accuracy: 0.0548 - f1_score: 0.0356 - loss: 3.7992 - precision: 0.0548 - recall: 0.05 ━━━━━━━━━━━━━━━━━━━━ 1:08 333ms/step - accuracy: 0.0563 - f1_score: 0.0359 - loss: 3.9290 - precision: 0.0563 - recall: 0.05 ━━━━━━━━━━━━━━━━━━━━ 1:06 328ms/step - accuracy: 0.0579 - f1_score: 0.0363 - loss: 4.0258 - precision: 0.0579 - recall: 0.05 ━━━━━━━━━━━━━━━━━━━━ 1:05 322ms/step - accuracy: 0.0591 - f1_score: 0.0366 - loss: 4.1140 - precision: 0.0591 - recall: 0.05 ━━━━━━━━━━━━━━━━━━━━ 1:04 318ms/step - accuracy: 0.0603 - f1_score: 0.0370 - loss: 4.1916 - precision: 0.0603 - recall: 0.06 ━━━━━━━━━━━━━━━━━━━━ 1:03 316ms/step - accuracy: 0.0613 - f1_score: 0.0373 - loss: 4.2755 - precision: 0.0613 - recall: 0.06 ━━━━━━━━━━━━━━━━━━━━ 1:02 314ms/step - accuracy: 0.0621 - f1_score: 0.0376 - loss: 4.3653 - precision: 0.0621 - recall: 0.06 ━━━━━━━━━━━━━━━━━━━━ 1:01 311ms/step - accuracy: 0.0627 - f1_score: 0.0378 - loss: 4.4652 - precision: 0.0627 - recall: 0.06 ━━━━━━━━━━━━━━━━━━━━ 1:01 310ms/step - accuracy: 0.0632 - f1_score: 0.0380 - loss: 4.5671 - precision: 0.0632 - recall: 0.06 ━━━━━━━━━━━━━━━━━━━━ 1:01 311ms/step - accuracy: 0.0638 - f1_score: 0.0382 - loss: 4.6634 - precision: 0.0638 - recall: 0.06 ━━━━━━━━━━━━━━━━━━━━ 1:00 310ms/step - accuracy: 0.0643 - f1_score: 0.0385 - loss: 4.7396 - precision: 0.0643 - recall: 0.06 ━━━━━━━━━━━━━━━━━━━━ 1:00 309ms/step - accuracy: 0.0649 - f1_score: 0.0387 - loss: 4.8000 - precision: 0.0649 - recall: 0.06 ━━━━━━━━━━━━━━━━━━━━ 59s 308ms/step - accuracy: 0.0655 - f1_score: 0.0389 - loss: 4.8461 - precision: 0.0655 - recall: 0.0655 ━━━━━━━━━━━━━━━━━━━━ 59s 306ms/step - accuracy: 0.0660 - f1_score: 0.0391 - loss: 4.9015 - precision: 0.0660 - recall: 0.066 ━━━━━━━━━━━━━━━━━━━━ 58s 305ms/step - accuracy: 0.0664 - f1_score: 0.0392 - loss: 4.9584 - precision: 0.0664 - recall: 0.066 ━━━━━━━━━━━━━━━━━━━━ 58s 304ms/step - accuracy: 0.0669 - f1_score: 0.0393 - loss: 5.0115 - precision: 0.0669 - recall: 0.066 ━━━━━━━━━━━━━━━━━━━━ 57s 304ms/step - accuracy: 0.0673 - f1_score: 0.0394 - loss: 5.0650 - precision: 0.0673 - recall: 0.067 ━━━━━━━━━━━━━━━━━━━━ 57s 303ms/step - accuracy: 0.0676 - f1_score: 0.0395 - loss: 5.1188 - precision: 0.0676 - recall: 0.067 ━━━━━━━━━━━━━━━━━━━━ 57s 303ms/step - accuracy: 0.0679 - f1_score: 0.0395 - loss: 5.1732 - precision: 0.0679 - recall: 0.067 ━━━━━━━━━━━━━━━━━━━━ 56s 302ms/step - accuracy: 0.0681 - f1_score: 0.0395 - loss: 5.2278 - precision: 0.0681 - recall: 0.068 ━━━━━━━━━━━━━━━━━━━━ 56s 303ms/step - accuracy: 0.0684 - f1_score: 0.0396 - loss: 5.2818 - precision: 0.0684 - recall: 0.068 ━━━━━━━━━━━━━━━━━━━━ 55s 302ms/step - accuracy: 0.0686 - f1_score: 0.0396 - loss: 5.3351 - precision: 0.0686 - recall: 0.068 ━━━━━━━━━━━━━━━━━━━━ 55s 302ms/step - accuracy: 0.0687 - f1_score: 0.0396 - loss: 5.3823 - precision: 0.0687 - recall: 0.068 ━━━━━━━━━━━━━━━━━━━━ 55s 301ms/step - accuracy: 0.0689 - f1_score: 0.0397 - loss: 5.4209 - precision: 0.0689 - recall: ...
# Epoch 2/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 2:01 568ms/step - accuracy: 0.0000e+00 - f1_score: 0.0000e+00 - loss: 4.1068 - precision: 0.0000e+00 - recall: 0.0000e+ ━━━━━━━━━━━━━━━━━━━━ 1:36 454ms/step - accuracy: 0.0000e+00 - f1_score: 0.0000e+00 - loss: 3.2989 - precision: 0.0000e+00 - recall: 0.0000e+ ━━━━━━━━━━━━━━━━━━━━ 1:41 478ms/step - accuracy: 0.0833 - f1_score: 6.6007e-04 - loss: 3.1113 - precision: 0.0833 - recall: 0.0833           ━━━━━━━━━━━━━━━━━━━━ 1:27 416ms/step - accuracy: 0.1113 - f1_score: 0.0010 - loss: 3.3423 - precision: 0.1113 - recall: 0.1113   ━━━━━━━━━━━━━━━━━━━━ 1:20 383ms/step - accuracy: 0.1203 - f1_score: 0.0012 - loss: 3.4296 - precision: 0.1203 - recall: 0.12 ━━━━━━━━━━━━━━━━━━━━ 1:15 360ms/step - accuracy: 0.1220 - f1_score: 0.0013 - loss: 3.4989 - precision: 0.1220 - recall: 0.12 ━━━━━━━━━━━━━━━━━━━━ 1:12 347ms/step - accuracy: 0.1218 - f1_score: 0.0014 - loss: 3.6041 - precision: 0.1218 - recall: 0.12 ━━━━━━━━━━━━━━━━━━━━ 1:09 334ms/step - accuracy: 0.1197 - f1_score: 0.0015 - loss: 3.6385 - precision: 0.1197 - recall: 0.11 ━━━━━━━━━━━━━━━━━━━━ 1:07 326ms/step - accuracy: 0.1292 - f1_score: 0.0019 - loss: 3.6199 - precision: 0.1292 - recall: 0.12 ━━━━━━━━━━━━━━━━━━━━ 1:06 323ms/step - accuracy: 0.1360 - f1_score: 0.0022 - loss: 3.6596 - precision: 0.1360 - recall: 0.13 ━━━━━━━━━━━━━━━━━━━━ 1:05 321ms/step - accuracy: 0.1406 - f1_score: 0.0024 - loss: 3.6946 - precision: 0.1406 - recall: 0.14 ━━━━━━━━━━━━━━━━━━━━ 1:04 319ms/step - accuracy: 0.1432 - f1_score: 0.0026 - loss: 3.7288 - precision: 0.1432 - recall: 0.14 ━━━━━━━━━━━━━━━━━━━━ 1:03 316ms/step - accuracy: 0.1457 - f1_score: 0.0030 - loss: 3.7657 - precision: 0.1457 - recall: 0.14 ━━━━━━━━━━━━━━━━━━━━ 1:02 312ms/step - accuracy: 0.1470 - f1_score: 0.0032 - loss: 3.8148 - precision: 0.1470 - recall: 0.14 ━━━━━━━━━━━━━━━━━━━━ 1:01 309ms/step - accuracy: 0.1473 - f1_score: 0.0034 - loss: 3.8711 - precision: 0.1473 - recall: 0.14 ━━━━━━━━━━━━━━━━━━━━ 1:01 307ms/step - accuracy: 0.1470 - f1_score: 0.0036 - loss: 3.9359 - precision: 0.1470 - recall: 0.14 ━━━━━━━━━━━━━━━━━━━━ 1:00 304ms/step - accuracy: 0.1468 - f1_score: 0.0039 - loss: 4.0066 - precision: 0.1468 - recall: 0.14 ━━━━━━━━━━━━━━━━━━━━ 59s 302ms/step - accuracy: 0.1470 - f1_score: 0.0042 - loss: 4.0744 - precision: 0.1470 - recall: 0.1470 ━━━━━━━━━━━━━━━━━━━━ 59s 301ms/step - accuracy: 0.1468 - f1_score: 0.0044 - loss: 4.1259 - precision: 0.1468 - recall: 0.146 ━━━━━━━━━━━━━━━━━━━━ 59s 303ms/step - accuracy: 0.1474 - f1_score: 0.0047 - loss: 4.1669 - precision: 0.1474 - recall: 0.147 ━━━━━━━━━━━━━━━━━━━━ 58s 303ms/step - accuracy: 0.1484 - f1_score: 0.0050 - loss: 4.1967 - precision: 0.1484 - recall: 0.148 ━━━━━━━━━━━━━━━━━━━━ 58s 303ms/step - accuracy: 0.1490 - f1_score: 0.0053 - loss: 4.2344 - precision: 0.1490 - recall: 0.149 ━━━━━━━━━━━━━━━━━━━━ 57s 302ms/step - accuracy: 0.1495 - f1_score: 0.0056 - loss: 4.2751 - precision: 0.1495 - recall: 0.149 ━━━━━━━━━━━━━━━━━━━━ 57s 301ms/step - accuracy: 0.1497 - f1_score: 0.0059 - loss: 4.3127 - precision: 0.1497 - recall: 0.149 ━━━━━━━━━━━━━━━━━━━━ 56s 300ms/step - accuracy: 0.1497 - f1_score: 0.0062 - loss: 4.3515 - precision: 0.1497 - recall: 0.149 ━━━━━━━━━━━━━━━━━━━━ 56s 299ms/step - accuracy: 0.1496 - f1_score: 0.0064 - loss: 4.3897 - precision: 0.1496 - recall: 0.149 ━━━━━━━━━━━━━━━━━━━━ 56s 299ms/step - accuracy: 0.1494 - f1_score: 0.0067 - loss: 4.4295 - precision: 0.1494 - recall: 0.149 ━━━━━━━━━━━━━━━━━━━━ 55s 298ms/step - accuracy: 0.1490 - f1_score: 0.0069 - loss: 4.4706 - precision: 0.1490 - recall: 0.149 ━━━━━━━━━━━━━━━━━━━━ 55s 297ms/step - accuracy: 0.1487 - f1_score: 0.0072 - loss: 4.5117 - precision: 0.1487 - recall: 0.148 ━━━━━━━━━━━━━━━━━━━━ 55s 297ms/step - accuracy: 0.1482 - f1_score: 0.0074 - loss: 4.5524 - precision: 0.1482 - recall: 0.148 ━━━━━━━━━━━━━━━━━━━━ 54s 296ms/step - accuracy: 0.1477 - f1_score: 0.0076 - loss: 4.5876 - precision: 0.1477 - recall: 0.147 ━━━━━━━━━━━━━━━━━━━━ 54s 295ms/step - accuracy: 0.1470 - f1_scor ...
# Epoch 3/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 1:56 544ms/step - accuracy: 0.0000e+00 - f1_score: 0.0000e+00 - loss: 3.1392 - precision: 0.0000e+00 - recall: 0.0000e+ ━━━━━━━━━━━━━━━━━━━━ 1:37 460ms/step - accuracy: 0.2500 - f1_score: 0.0017 - loss: 2.4193 - precision: 0.2500 - recall: 0.2500               ━━━━━━━━━━━━━━━━━━━━ 1:36 456ms/step - accuracy: 0.3611 - f1_score: 0.0024 - loss: 2.2898 - precision: 0.3611 - recall: 0.36 ━━━━━━━━━━━━━━━━━━━━ 1:28 419ms/step - accuracy: 0.3880 - f1_score: 0.0031 - loss: 2.4974 - precision: 0.3880 - recall: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:21 389ms/step - accuracy: 0.3942 - f1_score: 0.0037 - loss: 2.5727 - precision: 0.3942 - recall: 0.39 ━━━━━━━━━━━━━━━━━━━━ 1:16 367ms/step - accuracy: 0.3866 - f1_score: 0.0040 - loss: 2.6634 - precision: 0.3866 - recall: 0.38 ━━━━━━━━━━━━━━━━━━━━ 1:13 351ms/step - accuracy: 0.3754 - f1_score: 0.0043 - loss: 2.7851 - precision: 0.3754 - recall: 0.37 ━━━━━━━━━━━━━━━━━━━━ 1:10 341ms/step - accuracy: 0.3695 - f1_score: 0.0047 - loss: 2.8354 - precision: 0.3695 - recall: 0.36 ━━━━━━━━━━━━━━━━━━━━ 1:08 333ms/step - accuracy: 0.3732 - f1_score: 0.0053 - loss: 2.8368 - precision: 0.3732 - recall: 0.37 ━━━━━━━━━━━━━━━━━━━━ 1:07 327ms/step - accuracy: 0.3734 - f1_score: 0.0056 - loss: 2.8811 - precision: 0.3734 - recall: 0.37 ━━━━━━━━━━━━━━━━━━━━ 1:06 324ms/step - accuracy: 0.3746 - f1_score: 0.0062 - loss: 2.9127 - precision: 0.3746 - recall: 0.37 ━━━━━━━━━━━━━━━━━━━━ 1:04 319ms/step - accuracy: 0.3729 - f1_score: 0.0065 - loss: 2.9505 - precision: 0.3729 - recall: 0.37 ━━━━━━━━━━━━━━━━━━━━ 1:03 314ms/step - accuracy: 0.3706 - f1_score: 0.0071 - loss: 2.9894 - precision: 0.3706 - recall: 0.37 ━━━━━━━━━━━━━━━━━━━━ 1:02 310ms/step - accuracy: 0.3676 - f1_score: 0.0075 - loss: 3.0394 - precision: 0.3676 - recall: 0.36 ━━━━━━━━━━━━━━━━━━━━ 1:01 308ms/step - accuracy: 0.3649 - f1_score: 0.0081 - loss: 3.0927 - precision: 0.3649 - recall: 0.36 ━━━━━━━━━━━━━━━━━━━━ 1:00 306ms/step - accuracy: 0.3612 - f1_score: 0.0086 - loss: 3.1592 - precision: 0.3612 - recall: 0.36 ━━━━━━━━━━━━━━━━━━━━ 1:00 304ms/step - accuracy: 0.3575 - f1_score: 0.0090 - loss: 3.2261 - precision: 0.3575 - recall: 0.35 ━━━━━━━━━━━━━━━━━━━━ 59s 302ms/step - accuracy: 0.3541 - f1_score: 0.0095 - loss: 3.2917 - precision: 0.3541 - recall: 0.3541 ━━━━━━━━━━━━━━━━━━━━ 59s 303ms/step - accuracy: 0.3513 - f1_score: 0.0101 - loss: 3.3428 - precision: 0.3513 - recall: 0.351 ━━━━━━━━━━━━━━━━━━━━ 59s 303ms/step - accuracy: 0.3491 - f1_score: 0.0106 - loss: 3.3840 - precision: 0.3491 - recall: 0.349 ━━━━━━━━━━━━━━━━━━━━ 58s 302ms/step - accuracy: 0.3476 - f1_score: 0.0112 - loss: 3.4144 - precision: 0.3476 - recall: 0.347 ━━━━━━━━━━━━━━━━━━━━ 58s 301ms/step - accuracy: 0.3458 - f1_score: 0.0117 - loss: 3.4523 - precision: 0.3458 - recall: 0.345 ━━━━━━━━━━━━━━━━━━━━ 57s 301ms/step - accuracy: 0.3440 - f1_score: 0.0123 - loss: 3.4914 - precision: 0.3440 - recall: 0.344 ━━━━━━━━━━━━━━━━━━━━ 57s 300ms/step - accuracy: 0.3419 - f1_score: 0.0128 - loss: 3.5269 - precision: 0.3419 - recall: 0.341 ━━━━━━━━━━━━━━━━━━━━ 56s 300ms/step - accuracy: 0.3395 - f1_score: 0.0132 - loss: 3.5655 - precision: 0.3395 - recall: 0.339 ━━━━━━━━━━━━━━━━━━━━ 56s 300ms/step - accuracy: 0.3373 - f1_score: 0.0137 - loss: 3.6037 - precision: 0.3373 - recall: 0.337 ━━━━━━━━━━━━━━━━━━━━ 56s 299ms/step - accuracy: 0.3348 - f1_score: 0.0142 - loss: 3.6441 - precision: 0.3348 - recall: 0.334 ━━━━━━━━━━━━━━━━━━━━ 55s 298ms/step - accuracy: 0.3322 - f1_score: 0.0145 - loss: 3.6866 - precision: 0.3322 - recall: 0.332 ━━━━━━━━━━━━━━━━━━━━ 55s 298ms/step - accuracy: 0.3297 - f1_score: 0.0150 - loss: 3.7290 - precision: 0.3297 - recall: 0.329 ━━━━━━━━━━━━━━━━━━━━ 54s 297ms/step - accuracy: 0.3272 - f1_score: 0.0154 - loss: 3.7699 - precision: 0.3272 - recall: 0.327 ━━━━━━━━━━━━━━━━━━━━ 54s 298ms/step - accuracy: 0.3249 - f1_score: 0.0159 - loss: 3.8049 - precision: 0.3249 - recall: 0.324 ━━━━━━━━━━━━━━━━━━━━ 54s 298ms/step - accuracy: 0.3225 - f1_score: 0.0163 - loss: 3. ...
# Epoch 4/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 1:53 533ms/step - accuracy: 0.0000e+00 - f1_score: 0.0000e+00 - loss: 1.7807 - precision: 0.0000e+00 - recall: 0.0000e+ ━━━━━━━━━━━━━━━━━━━━ 1:45 495ms/step - accuracy: 0.2500 - f1_score: 0.0017 - loss: 1.3432 - precision: 0.2500 - recall: 0.2500               ━━━━━━━━━━━━━━━━━━━━ 1:44 494ms/step - accuracy: 0.3611 - f1_score: 0.0024 - loss: 1.3222 - precision: 0.3611 - recall: 0.36 ━━━━━━━━━━━━━━━━━━━━ 1:31 436ms/step - accuracy: 0.3919 - f1_score: 0.0033 - loss: 1.5053 - precision: 0.3919 - recall: 0.39 ━━━━━━━━━━━━━━━━━━━━ 1:23 399ms/step - accuracy: 0.4210 - f1_score: 0.0045 - loss: 1.5814 - precision: 0.4210 - recall: 0.42 ━━━━━━━━━━━━━━━━━━━━ 1:18 375ms/step - accuracy: 0.4255 - f1_score: 0.0051 - loss: 1.6983 - precision: 0.4255 - recall: 0.42 ━━━━━━━━━━━━━━━━━━━━ 1:16 365ms/step - accuracy: 0.4209 - f1_score: 0.0055 - loss: 1.8400 - precision: 0.4209 - recall: 0.42 ━━━━━━━━━━━━━━━━━━━━ 1:15 365ms/step - accuracy: 0.4234 - f1_score: 0.0063 - loss: 1.9152 - precision: 0.4234 - recall: 0.42 ━━━━━━━━━━━━━━━━━━━━ 1:12 354ms/step - accuracy: 0.4323 - f1_score: 0.0070 - loss: 1.9448 - precision: 0.4323 - recall: 0.43 ━━━━━━━━━━━━━━━━━━━━ 1:11 348ms/step - accuracy: 0.4356 - f1_score: 0.0075 - loss: 2.0098 - precision: 0.4356 - recall: 0.43 ━━━━━━━━━━━━━━━━━━━━ 1:10 345ms/step - accuracy: 0.4397 - f1_score: 0.0084 - loss: 2.0583 - precision: 0.4397 - recall: 0.43 ━━━━━━━━━━━━━━━━━━━━ 1:08 336ms/step - accuracy: 0.4404 - f1_score: 0.0089 - loss: 2.1058 - precision: 0.4404 - recall: 0.44 ━━━━━━━━━━━━━━━━━━━━ 1:06 331ms/step - accuracy: 0.4396 - f1_score: 0.0096 - loss: 2.1610 - precision: 0.4396 - recall: 0.43 ━━━━━━━━━━━━━━━━━━━━ 1:05 327ms/step - accuracy: 0.4374 - f1_score: 0.0103 - loss: 2.2253 - precision: 0.4374 - recall: 0.43 ━━━━━━━━━━━━━━━━━━━━ 1:04 324ms/step - accuracy: 0.4356 - f1_score: 0.0110 - loss: 2.2869 - precision: 0.4356 - recall: 0.43 ━━━━━━━━━━━━━━━━━━━━ 1:03 320ms/step - accuracy: 0.4325 - f1_score: 0.0116 - loss: 2.3583 - precision: 0.4325 - recall: 0.43 ━━━━━━━━━━━━━━━━━━━━ 1:03 318ms/step - accuracy: 0.4291 - f1_score: 0.0122 - loss: 2.4304 - precision: 0.4291 - recall: 0.42 ━━━━━━━━━━━━━━━━━━━━ 1:02 316ms/step - accuracy: 0.4257 - f1_score: 0.0128 - loss: 2.4988 - precision: 0.4257 - recall: 0.42 ━━━━━━━━━━━━━━━━━━━━ 1:01 315ms/step - accuracy: 0.4222 - f1_score: 0.0134 - loss: 2.5538 - precision: 0.4222 - recall: 0.42 ━━━━━━━━━━━━━━━━━━━━ 1:01 314ms/step - accuracy: 0.4194 - f1_score: 0.0140 - loss: 2.6000 - precision: 0.4194 - recall: 0.41 ━━━━━━━━━━━━━━━━━━━━ 1:00 313ms/step - accuracy: 0.4174 - f1_score: 0.0146 - loss: 2.6360 - precision: 0.4174 - recall: 0.41 ━━━━━━━━━━━━━━━━━━━━ 1:00 311ms/step - accuracy: 0.4150 - f1_score: 0.0152 - loss: 2.6787 - precision: 0.4150 - recall: 0.41 ━━━━━━━━━━━━━━━━━━━━ 59s 309ms/step - accuracy: 0.4127 - f1_score: 0.0159 - loss: 2.7202 - precision: 0.4127 - recall: 0.4127 ━━━━━━━━━━━━━━━━━━━━ 58s 308ms/step - accuracy: 0.4106 - f1_score: 0.0165 - loss: 2.7567 - precision: 0.4106 - recall: 0.410 ━━━━━━━━━━━━━━━━━━━━ 58s 306ms/step - accuracy: 0.4085 - f1_score: 0.0173 - loss: 2.7947 - precision: 0.4085 - recall: 0.408 ━━━━━━━━━━━━━━━━━━━━ 57s 305ms/step - accuracy: 0.4065 - f1_score: 0.0182 - loss: 2.8314 - precision: 0.4065 - recall: 0.406 ━━━━━━━━━━━━━━━━━━━━ 57s 305ms/step - accuracy: 0.4043 - f1_score: 0.0188 - loss: 2.8673 - precision: 0.4043 - recall: 0.404 ━━━━━━━━━━━━━━━━━━━━ 56s 304ms/step - accuracy: 0.4019 - f1_score: 0.0194 - loss: 2.9056 - precision: 0.4019 - recall: 0.401 ━━━━━━━━━━━━━━━━━━━━ 56s 303ms/step - accuracy: 0.3997 - f1_score: 0.0202 - loss: 2.9434 - precision: 0.3997 - recall: 0.399 ━━━━━━━━━━━━━━━━━━━━ 56s 304ms/step - accuracy: 0.3977 - f1_score: 0.0211 - loss: 2.9793 - precision: 0.3977 - recall: 0.397 ━━━━━━━━━━━━━━━━━━━━ 55s 303ms/step - accuracy: 0.3958 - f1_score: 0.0219 - loss: 3.0103 - precision: 0.3958 - recall: 0.395 ━━━━━━━━━━━━━━━━━━━━ 55s 303ms/step - accuracy: 0.3936 - f1_score: 0.0225 - loss: 3. ...
# Epoch 5/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 1:57 551ms/step - accuracy: 0.4062 - f1_score: 0.0029 - loss: 1.0888 - precision: 0.4062 - recall: 0.40 ━━━━━━━━━━━━━━━━━━━━ 1:40 472ms/step - accuracy: 0.5547 - f1_score: 0.0035 - loss: 0.8179 - precision: 0.5547 - recall: 0.55 ━━━━━━━━━━━━━━━━━━━━ 1:38 464ms/step - accuracy: 0.6094 - f1_score: 0.0037 - loss: 0.8631 - precision: 0.6094 - recall: 0.60 ━━━━━━━━━━━━━━━━━━━━ 1:25 407ms/step - accuracy: 0.6270 - f1_score: 0.0054 - loss: 0.9783 - precision: 0.6270 - recall: 0.62 ━━━━━━━━━━━━━━━━━━━━ 1:18 375ms/step - accuracy: 0.6466 - f1_score: 0.0083 - loss: 1.0350 - precision: 0.6466 - recall: 0.64 ━━━━━━━━━━━━━━━━━━━━ 1:14 358ms/step - accuracy: 0.6395 - f1_score: 0.0090 - loss: 1.1605 - precision: 0.6395 - recall: 0.63 ━━━━━━━━━━━━━━━━━━━━ 1:11 343ms/step - accuracy: 0.6234 - f1_score: 0.0096 - loss: 1.2833 - precision: 0.6234 - recall: 0.62 ━━━━━━━━━━━━━━━━━━━━ 1:09 336ms/step - accuracy: 0.6168 - f1_score: 0.0104 - loss: 1.3491 - precision: 0.6168 - recall: 0.61 ━━━━━━━━━━━━━━━━━━━━ 1:08 334ms/step - accuracy: 0.6169 - f1_score: 0.0112 - loss: 1.3784 - precision: 0.6169 - recall: 0.61 ━━━━━━━━━━━━━━━━━━━━ 1:07 329ms/step - accuracy: 0.6121 - f1_score: 0.0117 - loss: 1.4416 - precision: 0.6121 - recall: 0.61 ━━━━━━━━━━━━━━━━━━━━ 1:05 323ms/step - accuracy: 0.6091 - f1_score: 0.0127 - loss: 1.4894 - precision: 0.6091 - recall: 0.60 ━━━━━━━━━━━━━━━━━━━━ 1:04 319ms/step - accuracy: 0.6037 - f1_score: 0.0133 - loss: 1.5338 - precision: 0.6037 - recall: 0.60 ━━━━━━━━━━━━━━━━━━━━ 1:03 316ms/step - accuracy: 0.5974 - f1_score: 0.0141 - loss: 1.5903 - precision: 0.5974 - recall: 0.59 ━━━━━━━━━━━━━━━━━━━━ 1:03 314ms/step - accuracy: 0.5909 - f1_score: 0.0151 - loss: 1.6542 - precision: 0.5909 - recall: 0.59 ━━━━━━━━━━━━━━━━━━━━ 1:02 312ms/step - accuracy: 0.5851 - f1_score: 0.0160 - loss: 1.7119 - precision: 0.5851 - recall: 0.58 ━━━━━━━━━━━━━━━━━━━━ 1:01 309ms/step - accuracy: 0.5784 - f1_score: 0.0168 - loss: 1.7747 - precision: 0.5784 - recall: 0.57 ━━━━━━━━━━━━━━━━━━━━ 1:00 307ms/step - accuracy: 0.5714 - f1_score: 0.0176 - loss: 1.8441 - precision: 0.5714 - recall: 0.57 ━━━━━━━━━━━━━━━━━━━━ 1:00 305ms/step - accuracy: 0.5653 - f1_score: 0.0187 - loss: 1.9073 - precision: 0.5653 - recall: 0.56 ━━━━━━━━━━━━━━━━━━━━ 59s 303ms/step - accuracy: 0.5594 - f1_score: 0.0196 - loss: 1.9590 - precision: 0.5594 - recall: 0.5594 ━━━━━━━━━━━━━━━━━━━━ 58s 302ms/step - accuracy: 0.5542 - f1_score: 0.0204 - loss: 2.0035 - precision: 0.5542 - recall: 0.554 ━━━━━━━━━━━━━━━━━━━━ 58s 300ms/step - accuracy: 0.5502 - f1_score: 0.0212 - loss: 2.0388 - precision: 0.5502 - recall: 0.550 ━━━━━━━━━━━━━━━━━━━━ 57s 299ms/step - accuracy: 0.5458 - f1_score: 0.0220 - loss: 2.0792 - precision: 0.5458 - recall: 0.545 ━━━━━━━━━━━━━━━━━━━━ 57s 299ms/step - accuracy: 0.5416 - f1_score: 0.0229 - loss: 2.1177 - precision: 0.5416 - recall: 0.541 ━━━━━━━━━━━━━━━━━━━━ 57s 299ms/step - accuracy: 0.5383 - f1_score: 0.0240 - loss: 2.1507 - precision: 0.5383 - recall: 0.538 ━━━━━━━━━━━━━━━━━━━━ 56s 299ms/step - accuracy: 0.5351 - f1_score: 0.0251 - loss: 2.1854 - precision: 0.5351 - recall: 0.535 ━━━━━━━━━━━━━━━━━━━━ 56s 297ms/step - accuracy: 0.5321 - f1_score: 0.0263 - loss: 2.2181 - precision: 0.5321 - recall: 0.532 ━━━━━━━━━━━━━━━━━━━━ 55s 298ms/step - accuracy: 0.5291 - f1_score: 0.0274 - loss: 2.2491 - precision: 0.5291 - recall: 0.529 ━━━━━━━━━━━━━━━━━━━━ 55s 297ms/step - accuracy: 0.5258 - f1_score: 0.0283 - loss: 2.2819 - precision: 0.5258 - recall: 0.525 ━━━━━━━━━━━━━━━━━━━━ 55s 296ms/step - accuracy: 0.5229 - f1_score: 0.0294 - loss: 2.3133 - precision: 0.5229 - recall: 0.522 ━━━━━━━━━━━━━━━━━━━━ 54s 295ms/step - accuracy: 0.5203 - f1_score: 0.0307 - loss: 2.3426 - precision: 0.5203 - recall: 0.520 ━━━━━━━━━━━━━━━━━━━━ 54s 294ms/step - accuracy: 0.5179 - f1_score: 0.0319 - loss: 2.3677 - precision: 0.5179 - recall: 0.517 ━━━━━━━━━━━━━━━━━━━━ 53s 295ms/step - accuracy: 0.5153 - f1_score: 0.0330 - loss: 2.3886 - precision: 0.5153 - recal ...
# Epoch 6/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 2:08 599ms/step - accuracy: 0.4688 - f1_score: 0.0032 - loss: 0.7977 - precision: 0.4688 - recall: 0.46 ━━━━━━━━━━━━━━━━━━━━ 1:40 471ms/step - accuracy: 0.6016 - f1_score: 0.0037 - loss: 0.5989 - precision: 0.6016 - recall: 0.60 ━━━━━━━━━━━━━━━━━━━━ 1:42 485ms/step - accuracy: 0.6476 - f1_score: 0.0039 - loss: 0.6755 - precision: 0.6476 - recall: 0.64 ━━━━━━━━━━━━━━━━━━━━ 1:27 415ms/step - accuracy: 0.6771 - f1_score: 0.0068 - loss: 0.7379 - precision: 0.6771 - recall: 0.67 ━━━━━━━━━━━━━━━━━━━━ 1:19 379ms/step - accuracy: 0.7017 - f1_score: 0.0098 - loss: 0.7724 - precision: 0.7017 - recall: 0.70 ━━━━━━━━━━━━━━━━━━━━ 1:14 355ms/step - accuracy: 0.6958 - f1_score: 0.0106 - loss: 0.8866 - precision: 0.6958 - recall: 0.69 ━━━━━━━━━━━━━━━━━━━━ 1:11 344ms/step - accuracy: 0.6870 - f1_score: 0.0117 - loss: 0.9824 - precision: 0.6870 - recall: 0.68 ━━━━━━━━━━━━━━━━━━━━ 1:09 334ms/step - accuracy: 0.6841 - f1_score: 0.0130 - loss: 1.0327 - precision: 0.6841 - recall: 0.68 ━━━━━━━━━━━━━━━━━━━━ 1:07 326ms/step - accuracy: 0.6860 - f1_score: 0.0141 - loss: 1.0549 - precision: 0.6860 - recall: 0.68 ━━━━━━━━━━━━━━━━━━━━ 1:05 321ms/step - accuracy: 0.6828 - f1_score: 0.0150 - loss: 1.1079 - precision: 0.6828 - recall: 0.68 ━━━━━━━━━━━━━━━━━━━━ 1:04 318ms/step - accuracy: 0.6806 - f1_score: 0.0162 - loss: 1.1472 - precision: 0.6806 - recall: 0.68 ━━━━━━━━━━━━━━━━━━━━ 1:03 314ms/step - accuracy: 0.6773 - f1_score: 0.0174 - loss: 1.1877 - precision: 0.6773 - recall: 0.67 ━━━━━━━━━━━━━━━━━━━━ 1:03 313ms/step - accuracy: 0.6721 - f1_score: 0.0184 - loss: 1.2396 - precision: 0.6721 - recall: 0.67 ━━━━━━━━━━━━━━━━━━━━ 1:01 308ms/step - accuracy: 0.6664 - f1_score: 0.0197 - loss: 1.2964 - precision: 0.6664 - recall: 0.66 ━━━━━━━━━━━━━━━━━━━━ 1:01 306ms/step - accuracy: 0.6614 - f1_score: 0.0210 - loss: 1.3457 - precision: 0.6614 - recall: 0.66 ━━━━━━━━━━━━━━━━━━━━ 1:00 304ms/step - accuracy: 0.6556 - f1_score: 0.0221 - loss: 1.3994 - precision: 0.6556 - recall: 0.65 ━━━━━━━━━━━━━━━━━━━━ 59s 303ms/step - accuracy: 0.6494 - f1_score: 0.0233 - loss: 1.4573 - precision: 0.6494 - recall: 0.6494 ━━━━━━━━━━━━━━━━━━━━ 59s 301ms/step - accuracy: 0.6438 - f1_score: 0.0247 - loss: 1.5090 - precision: 0.6438 - recall: 0.643 ━━━━━━━━━━━━━━━━━━━━ 58s 299ms/step - accuracy: 0.6387 - f1_score: 0.0259 - loss: 1.5520 - precision: 0.6387 - recall: 0.638 ━━━━━━━━━━━━━━━━━━━━ 57s 297ms/step - accuracy: 0.6340 - f1_score: 0.0270 - loss: 1.5887 - precision: 0.6340 - recall: 0.634 ━━━━━━━━━━━━━━━━━━━━ 57s 296ms/step - accuracy: 0.6302 - f1_score: 0.0281 - loss: 1.6180 - precision: 0.6302 - recall: 0.630 ━━━━━━━━━━━━━━━━━━━━ 57s 295ms/step - accuracy: 0.6261 - f1_score: 0.0291 - loss: 1.6506 - precision: 0.6261 - recall: 0.626 ━━━━━━━━━━━━━━━━━━━━ 56s 295ms/step - accuracy: 0.6224 - f1_score: 0.0304 - loss: 1.6810 - precision: 0.6224 - recall: 0.622 ━━━━━━━━━━━━━━━━━━━━ 56s 295ms/step - accuracy: 0.6193 - f1_score: 0.0318 - loss: 1.7075 - precision: 0.6193 - recall: 0.619 ━━━━━━━━━━━━━━━━━━━━ 56s 296ms/step - accuracy: 0.6165 - f1_score: 0.0333 - loss: 1.7353 - precision: 0.6165 - recall: 0.616 ━━━━━━━━━━━━━━━━━━━━ 55s 295ms/step - accuracy: 0.6139 - f1_score: 0.0349 - loss: 1.7607 - precision: 0.6139 - recall: 0.613 ━━━━━━━━━━━━━━━━━━━━ 55s 294ms/step - accuracy: 0.6114 - f1_score: 0.0363 - loss: 1.7855 - precision: 0.6114 - recall: 0.611 ━━━━━━━━━━━━━━━━━━━━ 54s 293ms/step - accuracy: 0.6086 - f1_score: 0.0377 - loss: 1.8106 - precision: 0.6086 - recall: 0.608 ━━━━━━━━━━━━━━━━━━━━ 54s 293ms/step - accuracy: 0.6061 - f1_score: 0.0393 - loss: 1.8345 - precision: 0.6061 - recall: 0.606 ━━━━━━━━━━━━━━━━━━━━ 54s 293ms/step - accuracy: 0.6041 - f1_score: 0.0411 - loss: 1.8563 - precision: 0.6041 - recall: 0.604 ━━━━━━━━━━━━━━━━━━━━ 53s 292ms/step - accuracy: 0.6021 - f1_score: 0.0427 - loss: 1.8751 - precision: 0.6021 - recall: 0.602 ━━━━━━━━━━━━━━━━━━━━ 53s 292ms/step - accuracy: 0.6004 - f1_score: 0.0443 - loss: 1.8906 - precision: 0.6004 - recal ...
# Epoch 7/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 1:59 560ms/step - accuracy: 0.5312 - f1_score: 0.0034 - loss: 0.6635 - precision: 0.5312 - recall: 0.53 ━━━━━━━━━━━━━━━━━━━━ 1:42 481ms/step - accuracy: 0.6484 - f1_score: 0.0039 - loss: 0.4978 - precision: 0.6484 - recall: 0.64 ━━━━━━━━━━━━━━━━━━━━ 1:38 466ms/step - accuracy: 0.6927 - f1_score: 0.0047 - loss: 0.5701 - precision: 0.6927 - recall: 0.69 ━━━━━━━━━━━━━━━━━━━━ 1:28 419ms/step - accuracy: 0.7266 - f1_score: 0.0080 - loss: 0.5950 - precision: 0.7266 - recall: 0.72 ━━━━━━━━━━━━━━━━━━━━ 1:20 386ms/step - accuracy: 0.7500 - f1_score: 0.0109 - loss: 0.6179 - precision: 0.7500 - recall: 0.75 ━━━━━━━━━━━━━━━━━━━━ 1:15 362ms/step - accuracy: 0.7465 - f1_score: 0.0120 - loss: 0.6981 - precision: 0.7465 - recall: 0.74 ━━━━━━━━━━━━━━━━━━━━ 1:12 347ms/step - accuracy: 0.7387 - f1_score: 0.0132 - loss: 0.7685 - precision: 0.7387 - recall: 0.73 ━━━━━━━━━━━━━━━━━━━━ 1:10 339ms/step - accuracy: 0.7372 - f1_score: 0.0147 - loss: 0.8047 - precision: 0.7372 - recall: 0.73 ━━━━━━━━━━━━━━━━━━━━ 1:09 335ms/step - accuracy: 0.7394 - f1_score: 0.0159 - loss: 0.8201 - precision: 0.7394 - recall: 0.73 ━━━━━━━━━━━━━━━━━━━━ 1:07 327ms/step - accuracy: 0.7395 - f1_score: 0.0175 - loss: 0.8505 - precision: 0.7395 - recall: 0.73 ━━━━━━━━━━━━━━━━━━━━ 1:05 322ms/step - accuracy: 0.7397 - f1_score: 0.0190 - loss: 0.8711 - precision: 0.7397 - recall: 0.73 ━━━━━━━━━━━━━━━━━━━━ 1:04 320ms/step - accuracy: 0.7382 - f1_score: 0.0204 - loss: 0.9007 - precision: 0.7382 - recall: 0.73 ━━━━━━━━━━━━━━━━━━━━ 1:03 316ms/step - accuracy: 0.7343 - f1_score: 0.0217 - loss: 0.9388 - precision: 0.7343 - recall: 0.73 ━━━━━━━━━━━━━━━━━━━━ 1:03 314ms/step - accuracy: 0.7300 - f1_score: 0.0233 - loss: 0.9786 - precision: 0.7300 - recall: 0.73 ━━━━━━━━━━━━━━━━━━━━ 1:02 312ms/step - accuracy: 0.7270 - f1_score: 0.0250 - loss: 1.0114 - precision: 0.7270 - recall: 0.72 ━━━━━━━━━━━━━━━━━━━━ 1:01 309ms/step - accuracy: 0.7238 - f1_score: 0.0268 - loss: 1.0482 - precision: 0.7238 - recall: 0.72 ━━━━━━━━━━━━━━━━━━━━ 1:00 307ms/step - accuracy: 0.7202 - f1_score: 0.0287 - loss: 1.0861 - precision: 0.7202 - recall: 0.72 ━━━━━━━━━━━━━━━━━━━━ 1:00 306ms/step - accuracy: 0.7170 - f1_score: 0.0307 - loss: 1.1195 - precision: 0.7170 - recall: 0.71 ━━━━━━━━━━━━━━━━━━━━ 59s 306ms/step - accuracy: 0.7137 - f1_score: 0.0325 - loss: 1.1478 - precision: 0.7137 - recall: 0.7137 ━━━━━━━━━━━━━━━━━━━━ 59s 305ms/step - accuracy: 0.7104 - f1_score: 0.0341 - loss: 1.1717 - precision: 0.7104 - recall: 0.710 ━━━━━━━━━━━━━━━━━━━━ 58s 303ms/step - accuracy: 0.7078 - f1_score: 0.0356 - loss: 1.1904 - precision: 0.7078 - recall: 0.707 ━━━━━━━━━━━━━━━━━━━━ 58s 303ms/step - accuracy: 0.7048 - f1_score: 0.0372 - loss: 1.2111 - precision: 0.7048 - recall: 0.704 ━━━━━━━━━━━━━━━━━━━━ 57s 302ms/step - accuracy: 0.7026 - f1_score: 0.0390 - loss: 1.2297 - precision: 0.7026 - recall: 0.702 ━━━━━━━━━━━━━━━━━━━━ 57s 301ms/step - accuracy: 0.7009 - f1_score: 0.0409 - loss: 1.2457 - precision: 0.7009 - recall: 0.700 ━━━━━━━━━━━━━━━━━━━━ 56s 300ms/step - accuracy: 0.6991 - f1_score: 0.0429 - loss: 1.2629 - precision: 0.6991 - recall: 0.699 ━━━━━━━━━━━━━━━━━━━━ 56s 300ms/step - accuracy: 0.6976 - f1_score: 0.0450 - loss: 1.2779 - precision: 0.6976 - recall: 0.697 ━━━━━━━━━━━━━━━━━━━━ 56s 299ms/step - accuracy: 0.6960 - f1_score: 0.0469 - loss: 1.2933 - precision: 0.6960 - recall: 0.696 ━━━━━━━━━━━━━━━━━━━━ 55s 298ms/step - accuracy: 0.6942 - f1_score: 0.0489 - loss: 1.3093 - precision: 0.6942 - recall: 0.694 ━━━━━━━━━━━━━━━━━━━━ 55s 296ms/step - accuracy: 0.6927 - f1_score: 0.0511 - loss: 1.3242 - precision: 0.6927 - recall: 0.692 ━━━━━━━━━━━━━━━━━━━━ 54s 297ms/step - accuracy: 0.6916 - f1_score: 0.0534 - loss: 1.3373 - precision: 0.6916 - recall: 0.691 ━━━━━━━━━━━━━━━━━━━━ 54s 297ms/step - accuracy: 0.6904 - f1_score: 0.0555 - loss: 1.3488 - precision: 0.6904 - recall: 0.690 ━━━━━━━━━━━━━━━━━━━━ 54s 296ms/step - accuracy: 0.6895 - f1_score: 0.0576 - loss: 1.3581 - precision: 0.6895 - recal ...
# Epoch 8/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 2:02 570ms/step - accuracy: 0.6562 - f1_score: 0.0039 - loss: 0.6081 - precision: 0.6562 - recall: 0.65 ━━━━━━━━━━━━━━━━━━━━ 1:40 473ms/step - accuracy: 0.7422 - f1_score: 0.0042 - loss: 0.4562 - precision: 0.7422 - recall: 0.74 ━━━━━━━━━━━━━━━━━━━━ 1:39 469ms/step - accuracy: 0.7760 - f1_score: 0.0054 - loss: 0.4452 - precision: 0.7760 - recall: 0.77 ━━━━━━━━━━━━━━━━━━━━ 1:27 413ms/step - accuracy: 0.8027 - f1_score: 0.0087 - loss: 0.4238 - precision: 0.8027 - recall: 0.80 ━━━━━━━━━━━━━━━━━━━━ 1:18 373ms/step - accuracy: 0.8147 - f1_score: 0.0116 - loss: 0.4427 - precision: 0.8147 - recall: 0.81 ━━━━━━━━━━━━━━━━━━━━ 1:14 355ms/step - accuracy: 0.8048 - f1_score: 0.0127 - loss: 0.5031 - precision: 0.8048 - recall: 0.80 ━━━━━━━━━━━━━━━━━━━━ 1:11 345ms/step - accuracy: 0.7938 - f1_score: 0.0141 - loss: 0.5574 - precision: 0.7938 - recall: 0.79 ━━━━━━━━━━━━━━━━━━━━ 1:09 334ms/step - accuracy: 0.7893 - f1_score: 0.0156 - loss: 0.5861 - precision: 0.7893 - recall: 0.78 ━━━━━━━━━━━━━━━━━━━━ 1:08 331ms/step - accuracy: 0.7888 - f1_score: 0.0169 - loss: 0.5992 - precision: 0.7888 - recall: 0.78 ━━━━━━━━━━━━━━━━━━━━ 1:07 330ms/step - accuracy: 0.7880 - f1_score: 0.0186 - loss: 0.6192 - precision: 0.7880 - recall: 0.78 ━━━━━━━━━━━━━━━━━━━━ 1:06 324ms/step - accuracy: 0.7889 - f1_score: 0.0205 - loss: 0.6318 - precision: 0.7889 - recall: 0.78 ━━━━━━━━━━━━━━━━━━━━ 1:04 317ms/step - accuracy: 0.7885 - f1_score: 0.0222 - loss: 0.6568 - precision: 0.7885 - recall: 0.78 ━━━━━━━━━━━━━━━━━━━━ 1:03 314ms/step - accuracy: 0.7857 - f1_score: 0.0238 - loss: 0.6912 - precision: 0.7857 - recall: 0.78 ━━━━━━━━━━━━━━━━━━━━ 1:02 311ms/step - accuracy: 0.7837 - f1_score: 0.0258 - loss: 0.7228 - precision: 0.7837 - recall: 0.78 ━━━━━━━━━━━━━━━━━━━━ 1:01 308ms/step - accuracy: 0.7824 - f1_score: 0.0279 - loss: 0.7490 - precision: 0.7824 - recall: 0.78 ━━━━━━━━━━━━━━━━━━━━ 1:01 308ms/step - accuracy: 0.7811 - f1_score: 0.0301 - loss: 0.7749 - precision: 0.7811 - recall: 0.78 ━━━━━━━━━━━━━━━━━━━━ 1:00 306ms/step - accuracy: 0.7794 - f1_score: 0.0324 - loss: 0.8027 - precision: 0.7794 - recall: 0.77 ━━━━━━━━━━━━━━━━━━━━ 59s 303ms/step - accuracy: 0.7783 - f1_score: 0.0351 - loss: 0.8269 - precision: 0.7783 - recall: 0.7783 ━━━━━━━━━━━━━━━━━━━━ 59s 302ms/step - accuracy: 0.7764 - f1_score: 0.0372 - loss: 0.8486 - precision: 0.7764 - recall: 0.776 ━━━━━━━━━━━━━━━━━━━━ 58s 302ms/step - accuracy: 0.7747 - f1_score: 0.0393 - loss: 0.8666 - precision: 0.7747 - recall: 0.774 ━━━━━━━━━━━━━━━━━━━━ 58s 300ms/step - accuracy: 0.7734 - f1_score: 0.0413 - loss: 0.8806 - precision: 0.7734 - recall: 0.773 ━━━━━━━━━━━━━━━━━━━━ 57s 300ms/step - accuracy: 0.7719 - f1_score: 0.0433 - loss: 0.8951 - precision: 0.7719 - recall: 0.771 ━━━━━━━━━━━━━━━━━━━━ 57s 299ms/step - accuracy: 0.7710 - f1_score: 0.0456 - loss: 0.9071 - precision: 0.7710 - recall: 0.771 ━━━━━━━━━━━━━━━━━━━━ 57s 299ms/step - accuracy: 0.7704 - f1_score: 0.0479 - loss: 0.9171 - precision: 0.7704 - recall: 0.770 ━━━━━━━━━━━━━━━━━━━━ 56s 298ms/step - accuracy: 0.7696 - f1_score: 0.0503 - loss: 0.9308 - precision: 0.7696 - recall: 0.769 ━━━━━━━━━━━━━━━━━━━━ 56s 297ms/step - accuracy: 0.7691 - f1_score: 0.0528 - loss: 0.9420 - precision: 0.7691 - recall: 0.769 ━━━━━━━━━━━━━━━━━━━━ 55s 295ms/step - accuracy: 0.7686 - f1_score: 0.0552 - loss: 0.9535 - precision: 0.7686 - recall: 0.768 ━━━━━━━━━━━━━━━━━━━━ 55s 295ms/step - accuracy: 0.7679 - f1_score: 0.0577 - loss: 0.9646 - precision: 0.7679 - recall: 0.767 ━━━━━━━━━━━━━━━━━━━━ 55s 296ms/step - accuracy: 0.7675 - f1_score: 0.0603 - loss: 0.9747 - precision: 0.7675 - recall: 0.767 ━━━━━━━━━━━━━━━━━━━━ 54s 295ms/step - accuracy: 0.7673 - f1_score: 0.0631 - loss: 0.9833 - precision: 0.7673 - recall: 0.767 ━━━━━━━━━━━━━━━━━━━━ 54s 296ms/step - accuracy: 0.7669 - f1_score: 0.0657 - loss: 0.9907 - precision: 0.7669 - recall: 0.766 ━━━━━━━━━━━━━━━━━━━━ 53s 295ms/step - accuracy: 0.7668 - f1_score: 0.0682 - loss: 0.9964 - precision: 0.7668 - recal ...
# Epoch 9/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 2:00 561ms/step - accuracy: 0.8125 - f1_score: 0.0044 - loss: 0.3871 - precision: 0.8125 - recall: 0.81 ━━━━━━━━━━━━━━━━━━━━ 1:46 498ms/step - accuracy: 0.8594 - f1_score: 0.0046 - loss: 0.2904 - precision: 0.8594 - recall: 0.85 ━━━━━━━━━━━━━━━━━━━━ 1:44 494ms/step - accuracy: 0.8854 - f1_score: 0.0063 - loss: 0.2475 - precision: 0.8854 - recall: 0.88 ━━━━━━━━━━━━━━━━━━━━ 1:34 449ms/step - accuracy: 0.9023 - f1_score: 0.0096 - loss: 0.2193 - precision: 0.9023 - recall: 0.90 ━━━━━━━━━━━━━━━━━━━━ 1:25 408ms/step - accuracy: 0.8931 - f1_score: 0.0122 - loss: 0.2681 - precision: 0.8931 - recall: 0.89 ━━━━━━━━━━━━━━━━━━━━ 1:19 380ms/step - accuracy: 0.8771 - f1_score: 0.0136 - loss: 0.3303 - precision: 0.8771 - recall: 0.87 ━━━━━━━━━━━━━━━━━━━━ 1:15 363ms/step - accuracy: 0.8621 - f1_score: 0.0154 - loss: 0.3819 - precision: 0.8621 - recall: 0.86 ━━━━━━━━━━━━━━━━━━━━ 1:12 351ms/step - accuracy: 0.8540 - f1_score: 0.0171 - loss: 0.4111 - precision: 0.8540 - recall: 0.85 ━━━━━━━━━━━━━━━━━━━━ 1:11 345ms/step - accuracy: 0.8501 - f1_score: 0.0185 - loss: 0.4267 - precision: 0.8501 - recall: 0.85 ━━━━━━━━━━━━━━━━━━━━ 1:09 338ms/step - accuracy: 0.8473 - f1_score: 0.0205 - loss: 0.4440 - precision: 0.8473 - recall: 0.84 ━━━━━━━━━━━━━━━━━━━━ 1:07 331ms/step - accuracy: 0.8465 - f1_score: 0.0226 - loss: 0.4545 - precision: 0.8465 - recall: 0.84 ━━━━━━━━━━━━━━━━━━━━ 1:06 329ms/step - accuracy: 0.8449 - f1_score: 0.0244 - loss: 0.4780 - precision: 0.8449 - recall: 0.84 ━━━━━━━━━━━━━━━━━━━━ 1:05 325ms/step - accuracy: 0.8411 - f1_score: 0.0262 - loss: 0.5055 - precision: 0.8411 - recall: 0.84 ━━━━━━━━━━━━━━━━━━━━ 1:04 321ms/step - accuracy: 0.8386 - f1_score: 0.0284 - loss: 0.5295 - precision: 0.8386 - recall: 0.83 ━━━━━━━━━━━━━━━━━━━━ 1:03 317ms/step - accuracy: 0.8370 - f1_score: 0.0307 - loss: 0.5484 - precision: 0.8370 - recall: 0.83 ━━━━━━━━━━━━━━━━━━━━ 1:02 314ms/step - accuracy: 0.8356 - f1_score: 0.0332 - loss: 0.5662 - precision: 0.8356 - recall: 0.83 ━━━━━━━━━━━━━━━━━━━━ 1:01 311ms/step - accuracy: 0.8336 - f1_score: 0.0357 - loss: 0.5860 - precision: 0.8336 - recall: 0.83 ━━━━━━━━━━━━━━━━━━━━ 1:00 309ms/step - accuracy: 0.8322 - f1_score: 0.0385 - loss: 0.6021 - precision: 0.8322 - recall: 0.83 ━━━━━━━━━━━━━━━━━━━━ 1:00 307ms/step - accuracy: 0.8302 - f1_score: 0.0409 - loss: 0.6168 - precision: 0.8302 - recall: 0.83 ━━━━━━━━━━━━━━━━━━━━ 59s 307ms/step - accuracy: 0.8283 - f1_score: 0.0432 - loss: 0.6291 - precision: 0.8283 - recall: 0.8283 ━━━━━━━━━━━━━━━━━━━━ 59s 307ms/step - accuracy: 0.8267 - f1_score: 0.0453 - loss: 0.6387 - precision: 0.8267 - recall: 0.826 ━━━━━━━━━━━━━━━━━━━━ 59s 306ms/step - accuracy: 0.8257 - f1_score: 0.0476 - loss: 0.6465 - precision: 0.8257 - recall: 0.825 ━━━━━━━━━━━━━━━━━━━━ 58s 304ms/step - accuracy: 0.8250 - f1_score: 0.0502 - loss: 0.6534 - precision: 0.8250 - recall: 0.825 ━━━━━━━━━━━━━━━━━━━━ 57s 303ms/step - accuracy: 0.8242 - f1_score: 0.0527 - loss: 0.6601 - precision: 0.8242 - recall: 0.824 ━━━━━━━━━━━━━━━━━━━━ 57s 302ms/step - accuracy: 0.8231 - f1_score: 0.0552 - loss: 0.6689 - precision: 0.8231 - recall: 0.823 ━━━━━━━━━━━━━━━━━━━━ 56s 301ms/step - accuracy: 0.8225 - f1_score: 0.0580 - loss: 0.6759 - precision: 0.8225 - recall: 0.822 ━━━━━━━━━━━━━━━━━━━━ 56s 300ms/step - accuracy: 0.8217 - f1_score: 0.0606 - loss: 0.6839 - precision: 0.8217 - recall: 0.821 ━━━━━━━━━━━━━━━━━━━━ 55s 299ms/step - accuracy: 0.8212 - f1_score: 0.0634 - loss: 0.6907 - precision: 0.8212 - recall: 0.821 ━━━━━━━━━━━━━━━━━━━━ 55s 301ms/step - accuracy: 0.8209 - f1_score: 0.0663 - loss: 0.6968 - precision: 0.8209 - recall: 0.820 ━━━━━━━━━━━━━━━━━━━━ 55s 300ms/step - accuracy: 0.8208 - f1_score: 0.0694 - loss: 0.7017 - precision: 0.8208 - recall: 0.820 ━━━━━━━━━━━━━━━━━━━━ 54s 298ms/step - accuracy: 0.8205 - f1_score: 0.0722 - loss: 0.7058 - precision: 0.8205 - recall: 0.820 ━━━━━━━━━━━━━━━━━━━━ 54s 298ms/step - accuracy: 0.8203 - f1_score: 0.0750 - loss: 0.7090 - precision: 0.8203 - recal ...
# Epoch 10/10
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 1:54 534ms/step - accuracy: 0.9062 - f1_score: 0.0047 - loss: 0.1537 - precision: 0.9062 - recall: 0.90 ━━━━━━━━━━━━━━━━━━━━ 1:38 462ms/step - accuracy: 0.9297 - f1_score: 0.0048 - loss: 0.1154 - precision: 0.9297 - recall: 0.92 ━━━━━━━━━━━━━━━━━━━━ 1:41 480ms/step - accuracy: 0.9427 - f1_score: 0.0065 - loss: 0.0957 - precision: 0.9427 - recall: 0.94 ━━━━━━━━━━━━━━━━━━━━ 1:35 452ms/step - accuracy: 0.9512 - f1_score: 0.0098 - loss: 0.0875 - precision: 0.9512 - recall: 0.95 ━━━━━━━━━━━━━━━━━━━━ 1:29 425ms/step - accuracy: 0.9384 - f1_score: 0.0124 - loss: 0.1560 - precision: 0.9384 - recall: 0.93 ━━━━━━━━━━━━━━━━━━━━ 1:22 394ms/step - accuracy: 0.9261 - f1_score: 0.0140 - loss: 0.2108 - precision: 0.9261 - recall: 0.92 ━━━━━━━━━━━━━━━━━━━━ 1:17 373ms/step - accuracy: 0.9144 - f1_score: 0.0162 - loss: 0.2504 - precision: 0.9144 - recall: 0.91 ━━━━━━━━━━━━━━━━━━━━ 1:14 361ms/step - accuracy: 0.9075 - f1_score: 0.0180 - loss: 0.2737 - precision: 0.9075 - recall: 0.90 ━━━━━━━━━━━━━━━━━━━━ 1:11 349ms/step - accuracy: 0.9031 - f1_score: 0.0195 - loss: 0.2871 - precision: 0.9031 - recall: 0.90 ━━━━━━━━━━━━━━━━━━━━ 1:09 340ms/step - accuracy: 0.9006 - f1_score: 0.0216 - loss: 0.2993 - precision: 0.9006 - recall: 0.90 ━━━━━━━━━━━━━━━━━━━━ 1:07 331ms/step - accuracy: 0.8991 - f1_score: 0.0238 - loss: 0.3082 - precision: 0.8991 - recall: 0.89 ━━━━━━━━━━━━━━━━━━━━ 1:05 324ms/step - accuracy: 0.8973 - f1_score: 0.0258 - loss: 0.3294 - precision: 0.8973 - recall: 0.89 ━━━━━━━━━━━━━━━━━━━━ 1:05 324ms/step - accuracy: 0.8944 - f1_score: 0.0278 - loss: 0.3504 - precision: 0.8944 - recall: 0.89 ━━━━━━━━━━━━━━━━━━━━ 1:04 320ms/step - accuracy: 0.8924 - f1_score: 0.0302 - loss: 0.3683 - precision: 0.8924 - recall: 0.89 ━━━━━━━━━━━━━━━━━━━━ 1:03 317ms/step - accuracy: 0.8913 - f1_score: 0.0326 - loss: 0.3816 - precision: 0.8913 - recall: 0.89 ━━━━━━━━━━━━━━━━━━━━ 1:02 314ms/step - accuracy: 0.8905 - f1_score: 0.0354 - loss: 0.3924 - precision: 0.8905 - recall: 0.89 ━━━━━━━━━━━━━━━━━━━━ 1:01 311ms/step - accuracy: 0.8894 - f1_score: 0.0382 - loss: 0.4062 - precision: 0.8894 - recall: 0.88 ━━━━━━━━━━━━━━━━━━━━ 1:01 310ms/step - accuracy: 0.8888 - f1_score: 0.0412 - loss: 0.4169 - precision: 0.8888 - recall: 0.88 ━━━━━━━━━━━━━━━━━━━━ 1:00 309ms/step - accuracy: 0.8875 - f1_score: 0.0439 - loss: 0.4270 - precision: 0.8875 - recall: 0.88 ━━━━━━━━━━━━━━━━━━━━ 1:00 308ms/step - accuracy: 0.8865 - f1_score: 0.0465 - loss: 0.4355 - precision: 0.8865 - recall: 0.88 ━━━━━━━━━━━━━━━━━━━━ 59s 309ms/step - accuracy: 0.8857 - f1_score: 0.0488 - loss: 0.4423 - precision: 0.8857 - recall: 0.8857 ━━━━━━━━━━━━━━━━━━━━ 59s 308ms/step - accuracy: 0.8852 - f1_score: 0.0514 - loss: 0.4473 - precision: 0.8852 - recall: 0.885 ━━━━━━━━━━━━━━━━━━━━ 59s 308ms/step - accuracy: 0.8850 - f1_score: 0.0542 - loss: 0.4512 - precision: 0.8850 - recall: 0.885 ━━━━━━━━━━━━━━━━━━━━ 58s 306ms/step - accuracy: 0.8847 - f1_score: 0.0569 - loss: 0.4547 - precision: 0.8847 - recall: 0.884 ━━━━━━━━━━━━━━━━━━━━ 58s 306ms/step - accuracy: 0.8842 - f1_score: 0.0597 - loss: 0.4603 - precision: 0.8842 - recall: 0.884 ━━━━━━━━━━━━━━━━━━━━ 57s 305ms/step - accuracy: 0.8838 - f1_score: 0.0627 - loss: 0.4651 - precision: 0.8838 - recall: 0.883 ━━━━━━━━━━━━━━━━━━━━ 57s 304ms/step - accuracy: 0.8834 - f1_score: 0.0655 - loss: 0.4699 - precision: 0.8834 - recall: 0.883 ━━━━━━━━━━━━━━━━━━━━ 56s 303ms/step - accuracy: 0.8832 - f1_score: 0.0686 - loss: 0.4738 - precision: 0.8832 - recall: 0.883 ━━━━━━━━━━━━━━━━━━━━ 56s 304ms/step - accuracy: 0.8831 - f1_score: 0.0717 - loss: 0.4770 - precision: 0.8831 - recall: 0.883 ━━━━━━━━━━━━━━━━━━━━ 56s 303ms/step - accuracy: 0.8832 - f1_score: 0.0750 - loss: 0.4796 - precision: 0.8832 - recall: 0.883 ━━━━━━━━━━━━━━━━━━━━ 55s 303ms/step - accuracy: 0.8831 - f1_score: 0.0781 - loss: 0.4816 - precision: 0.8831 - recall: 0.883 ━━━━━━━━━━━━━━━━━━━━ 55s 303ms/step - accuracy: 0.8831 - f1_score: 0.0811 - loss: 0.4831 - precision: 0.8831 - recal ...

# %%
# Evaluate
results = best_model.evaluate(test_dataset, return_dict=True, verbose=0)
print("\nTest set results:")
for metric_name, value in results.items():
    print(f"{metric_name}: {value:.4f}")
# Out:
# Test set results:
# accuracy: 0.0271
# f1_score: 0.0294
# loss: 9.6477
# precision: 0.0271
# recall: 0.0271

# %% [markdown]
# <a class="anchor" id="eleven-bullet">
# <d style="color:white;">
#
# ### 2.4. Functional with more layers
# </a>
# </d>

# %% [markdown]
# <a class="anchor" id="twelve-bullet">
# <d style="color:white;">
#
# ### 2.5. Class Imbalance - last try
# </a>
# </d>
